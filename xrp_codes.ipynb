# %% [markdown]
# only close price, no validation included

# %%
import warnings
warnings.simplefilter("ignore")
import pandas as pd
import yfinance as yf
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout, BatchNormalization
from sklearn.metrics import mean_squared_error
from keras.regularizers import l2
import random

# Set seeds for reproducibility
np.random.seed(42)
tf.random.set_seed(42)
random.seed(42)

# Check if TensorFlow is using a GPU
if tf.config.list_physical_devices('GPU'):
    print("Using GPU for training.")
else:
    print("No GPU detected, training on CPU.")

# Step 1: Fetch Close price data for XRP
def fetch_xrp_data(start_date, end_date):
    data = yf.download('XRP-USD', start=start_date, end=end_date)
    return data[['Close']]  # Select Close price data

xrp_data = fetch_xrp_data('2020-01-01', '2024-01-01')

# Check if data was fetched successfully
if xrp_data.empty:
    raise SystemExit("Failed to fetch data. Exiting.")

xrp_data.dropna(inplace=True)  # Remove any rows with missing values

# Step 2: Preprocess data and scale features
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(xrp_data[['Close']])  # Only scale 'Close' price

# Step 3: Prepare the dataset for training and testing (time series split)
def create_dataset(data, time_step):
    X, y = [], []
    for i in range(len(data) - time_step - 1):
        X.append(data[i:(i + time_step), 0])  # Use only the 'Close' price
        y.append(data[i + time_step, 0])  # Predict 'Close' price
    return np.array(X), np.array(y)

time_step = 60
X, y = create_dataset(scaled_data, time_step)

# Reshape data for LSTM model
X = X.reshape(X.shape[0], X.shape[1], 1)  # Adjusted for single feature (Close price)

# Step 4: Split the data into training and testing sets
train_size_ratio = 0.9
train_size = int(len(X) * train_size_ratio)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

print(f"Training data shape: {X_train.shape}, {y_train.shape}")
print(f"Test data shape: {X_test.shape}, {y_test.shape}")

# Step 5: Build and compile the LSTM model
def build_lstm_model(input_shape):
    model = Sequential()
    model.add(LSTM(units=150, return_sequences=True, input_shape=input_shape, kernel_regularizer=l2(0.001)))
    model.add(Dropout(0.3))
    model.add(BatchNormalization())
    model.add(LSTM(units=150, return_sequences=False, kernel_regularizer=l2(0.001)))
    model.add(Dropout(0.3))
    model.add(Dense(units=100, activation='relu', kernel_regularizer=l2(0.001)))
    model.add(Dense(units=1))  # Predict the 'Close' price
    return model

model = build_lstm_model((X_train.shape[1], X_train.shape[2]))
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001), loss='mean_squared_error')

# Step 6: Train the model
history = model.fit(X_train, y_train, epochs=500, batch_size=32, verbose=1)

# Step 7: Evaluate the model on the test set
test_loss = model.evaluate(X_test, y_test)
print(f"Test loss: {test_loss}")

# Step 8: Prepare test data and make predictions
def make_predictions(model, data, time_step, scaler):
    test_data = data[-time_step:]
    X_test = test_data.reshape(1, time_step, 1)  # Adjust shape for prediction
    predicted_price = model.predict(X_test)
    predicted_price_rescaled = scaler.inverse_transform([[predicted_price[0][0]]])[0][0]  # Rescale predicted price
    return predicted_price_rescaled

predicted_price_rescaled = make_predictions(model, scaled_data, time_step, scaler)

# Step 9: Get actual price and create a comparison DataFrame
actual_price = xrp_data['Close'][-1]  # Last actual price

comparison_df = pd.DataFrame({
    'Actual Price': [actual_price],
    'Predicted Price': [predicted_price_rescaled]
})

# Display the comparison DataFrame
print(comparison_df)

# Step 10: Calculate RMSE for the prediction
rmse = np.sqrt(mean_squared_error([actual_price], [predicted_price_rescaled]))
print(f"RMSE: {rmse}")

# Save the comparison to a CSV file
comparison_df.to_csv('actual_vs_predicted_xrp_optimized.csv', index=False)

# Save table as PNG image
def save_table_as_image(data, filename, title):
    fig, ax = plt.subplots(figsize=(8, 2.5))
    ax.set_title(title, fontsize=12, fontweight='bold', pad=10)
    ax.axis('off')
    tbl = ax.table(cellText=data.values, colLabels=data.columns, cellLoc='center', loc='center')
    tbl.auto_set_font_size(False)
    tbl.set_fontsize(10)
    tbl.scale(1.2, 1.2)
    plt.savefig(filename, bbox_inches='tight', dpi=300)
    plt.close()

save_table_as_image(comparison_df, 'xrp_comparison_table.png', 'XRP (XRP) Comparison: Actual vs Predicted Price')

# Save test loss plot as PNG image with test loss in the title
def save_test_loss_plot(history, filename, title, test_loss):
    plt.figure(figsize=(10, 6))
    plt.plot(history.history['loss'], label='Training Loss')
    plt.title(f"{title} (Test Loss: {test_loss:.4f})", fontsize=12, fontweight='bold')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)
    plt.savefig(filename, bbox_inches='tight', dpi=300)
    plt.close()

save_test_loss_plot(history, 'xrp_test_loss_plot.png', 'XRP (XRP) Training Loss Over Epochs', test_loss)

# Plot and save the prediction results
plt.figure(figsize=(12, 6))
plt.plot(xrp_data.index, xrp_data['Close'], label='Actual Price', color='blue')  # Actual price
plt.scatter(xrp_data.index[-1], predicted_price_rescaled, color='red', label='Predicted Price', marker='x', s=100)  # Predicted price
plt.title(f'XRP (XRP) Price Prediction: Actual vs Predicted (RMSE: {rmse:.4f})', fontsize=14, fontweight='bold', pad=15)
plt.xlabel('Date', fontsize=12, labelpad=10)
plt.ylabel('Price (USD)', fontsize=12, labelpad=10)
plt.grid(visible=True, linestyle='--', alpha=0.6)
plt.legend(fontsize=12)
plt.savefig('xrp_price_prediction_with_marker.png', bbox_inches='tight', dpi=300)
plt.show()

# Inform user of saved files
print("Files saved:")
print("1. Comparison table: 'xrp_comparison_table.png'")
print("2. Test loss plot: 'xrp_test_loss_plot.png'")
print("3. Results plot: 'xrp_price_prediction_with_marker.png'")
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Using GPU for training.
# Training data shape: (1260, 60, 1), (1260,)
# Test data shape: (140, 60, 1), (140,)
# Epoch 1/500
# 40/40 [==============================] - 4s 16ms/step - loss: 0.3749
# Epoch 2/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.3498
# Epoch 3/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.3312
# Epoch 4/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.3127
# Epoch 5/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.2957
# Epoch 6/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.2793
# Epoch 7/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.2637
# Epoch 8/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.2489
# Epoch 9/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.2353
# Epoch 10/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.2222
# Epoch 11/500
# 40/40 [==============================] - 1s 19ms/step - loss: 0.2096
# Epoch 12/500
# 40/40 [==============================] - 1s 18ms/step - loss: 0.1979
# Epoch 13/500
# 40/40 [==============================] - 1s 17ms/step - loss: 0.1869
# Epoch 14/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.1766
# Epoch 15/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.1673
# Epoch 16/500
# 40/40 [==============================] - 1s 17ms/step - loss: 0.1584
# Epoch 17/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.1495
# Epoch 18/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.1420
# Epoch 19/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.1348
# Epoch 20/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.1276
# Epoch 21/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.1210
# Epoch 22/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.1148
# Epoch 23/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.1093
# Epoch 24/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.1037
# Epoch 25/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0990
# Epoch 26/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0939
# Epoch 27/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0895
# Epoch 28/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0852
# Epoch 29/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0817
# Epoch 30/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0779
# Epoch 31/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0741
# Epoch 32/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0713
# Epoch 33/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0676
# Epoch 34/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0651
# Epoch 35/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0617
# Epoch 36/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0592
# Epoch 37/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0571
# Epoch 38/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0545
# Epoch 39/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0523
# Epoch 40/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0502
# Epoch 41/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0481
# Epoch 42/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0463
# Epoch 43/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0445
# Epoch 44/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0428
# Epoch 45/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0408
# Epoch 46/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0396
# Epoch 47/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0379
# Epoch 48/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0364
# Epoch 49/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0350
# Epoch 50/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0337
# Epoch 51/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0329
# Epoch 52/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0315
# Epoch 53/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0308
# Epoch 54/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0291
# Epoch 55/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0280
# Epoch 56/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0274
# Epoch 57/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0262
# Epoch 58/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0251
# Epoch 59/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0245
# Epoch 60/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0236
# Epoch 61/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0225
# Epoch 62/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0223
# Epoch 63/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0211
# Epoch 64/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0203
# Epoch 65/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0197
# Epoch 66/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0189
# Epoch 67/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0187
# Epoch 68/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0175
# Epoch 69/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0174
# Epoch 70/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0169
# Epoch 71/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0159
# Epoch 72/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0154
# Epoch 73/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0153
# Epoch 74/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0145
# Epoch 75/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0141
# Epoch 76/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0139
# Epoch 77/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0131
# Epoch 78/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0126
# Epoch 79/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0125
# Epoch 80/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0122
# Epoch 81/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0114
# Epoch 82/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0116
# Epoch 83/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0108
# Epoch 84/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0106
# Epoch 85/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0101
# Epoch 86/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0101
# Epoch 87/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0095
# Epoch 88/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0094
# Epoch 89/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0092
# Epoch 90/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0091
# Epoch 91/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0088
# Epoch 92/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0086
# Epoch 93/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0082
# Epoch 94/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0078
# Epoch 95/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0077
# Epoch 96/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0075
# Epoch 97/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0076
# Epoch 98/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0075
# Epoch 99/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0070
# Epoch 100/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0071
# Epoch 101/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0069
# Epoch 102/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0067
# Epoch 103/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0064
# Epoch 104/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0063
# Epoch 105/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0059
# Epoch 106/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0061
# Epoch 107/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0059
# Epoch 108/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0055
# Epoch 109/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0059
# Epoch 110/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0053
# Epoch 111/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0054
# Epoch 112/500
# 40/40 [==============================] - 1s 17ms/step - loss: 0.0052
# Epoch 113/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0051
# Epoch 114/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0052
# Epoch 115/500
# 40/40 [==============================] - 1s 18ms/step - loss: 0.0048
# Epoch 116/500
# 40/40 [==============================] - 1s 17ms/step - loss: 0.0049
# Epoch 117/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0049
# Epoch 118/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0046
# Epoch 119/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0045
# Epoch 120/500
# 40/40 [==============================] - 1s 17ms/step - loss: 0.0043
# Epoch 121/500
# 40/40 [==============================] - 1s 17ms/step - loss: 0.0041
# Epoch 122/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0044
# Epoch 123/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0044
# Epoch 124/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0042
# Epoch 125/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0039
# Epoch 126/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0040
# Epoch 127/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0040
# Epoch 128/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0038
# Epoch 129/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0042
# Epoch 130/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0040
# Epoch 131/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0040
# Epoch 132/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0041
# Epoch 133/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0036
# Epoch 134/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0040
# Epoch 135/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0034
# Epoch 136/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0042
# Epoch 137/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0037
# Epoch 138/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0039
# Epoch 139/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0036
# Epoch 140/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0036
# Epoch 141/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0032
# Epoch 142/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0038
# Epoch 143/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0032
# Epoch 144/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0036
# Epoch 145/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0036
# Epoch 146/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0033
# Epoch 147/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0034
# Epoch 148/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0032
# Epoch 149/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0032
# Epoch 150/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0032
# Epoch 151/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0032
# Epoch 152/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0034
# Epoch 153/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0031
# Epoch 154/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0032
# Epoch 155/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0035
# Epoch 156/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0035
# Epoch 157/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0033
# Epoch 158/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0029
# Epoch 159/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0036
# Epoch 160/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0030
# Epoch 161/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0029
# Epoch 162/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0028
# Epoch 163/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0028
# Epoch 164/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0028
# Epoch 165/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0028
# Epoch 166/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0032
# Epoch 167/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0028
# Epoch 168/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0033
# Epoch 169/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0033
# Epoch 170/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0028
# Epoch 171/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0035
# Epoch 172/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0028
# Epoch 173/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0026
# Epoch 174/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0029
# Epoch 175/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0028
# Epoch 176/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0028
# Epoch 177/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0031
# Epoch 178/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0030
# Epoch 179/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0029
# Epoch 180/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0027
# Epoch 181/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0030
# Epoch 182/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0029
# Epoch 183/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0028
# Epoch 184/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0027
# Epoch 185/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0028
# Epoch 186/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0027
# Epoch 187/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0028
# Epoch 188/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0028
# Epoch 189/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0028
# Epoch 190/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0026
# Epoch 191/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0027
# Epoch 192/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0026
# Epoch 193/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0028
# Epoch 194/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0029
# Epoch 195/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0027
# Epoch 196/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0027
# Epoch 197/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0026
# Epoch 198/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0026
# Epoch 199/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0028
# Epoch 200/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0028
# Epoch 201/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0026
# Epoch 202/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0027
# Epoch 203/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0027
# Epoch 204/500
# 40/40 [==============================] - 1s 17ms/step - loss: 0.0027
# Epoch 205/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0028
# Epoch 206/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0025
# Epoch 207/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0026
# Epoch 208/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0024
# Epoch 209/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0024
# Epoch 210/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0025
# Epoch 211/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0027
# Epoch 212/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0025
# Epoch 213/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0027
# Epoch 214/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0025
# Epoch 215/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0026
# Epoch 216/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0025
# Epoch 217/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0023
# Epoch 218/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0021
# Epoch 219/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0025
# Epoch 220/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0024
# Epoch 221/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0025
# Epoch 222/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0028
# Epoch 223/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0025
# Epoch 224/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0024
# Epoch 225/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0024
# Epoch 226/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0028
# Epoch 227/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0023
# Epoch 228/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0024
# Epoch 229/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0024
# Epoch 230/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0025
# Epoch 231/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0025
# Epoch 232/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0025
# Epoch 233/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0023
# Epoch 234/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0024
# Epoch 235/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0023
# Epoch 236/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0024
# Epoch 237/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0026
# Epoch 238/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0022
# Epoch 239/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0023
# Epoch 240/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0022
# Epoch 241/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0022
# Epoch 242/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0021
# Epoch 243/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0020
# Epoch 244/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0021
# Epoch 245/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0021
# Epoch 246/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0022
# Epoch 247/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0021
# Epoch 248/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0022
# Epoch 249/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0020
# Epoch 250/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0020
# Epoch 251/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0020
# Epoch 252/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0023
# Epoch 253/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0023
# Epoch 254/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0022
# Epoch 255/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0021
# Epoch 256/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0020
# Epoch 257/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0020
# Epoch 258/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0021
# Epoch 259/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0020
# Epoch 260/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0020
# Epoch 261/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0020
# Epoch 262/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0019
# Epoch 263/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0021
# Epoch 264/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0020
# Epoch 265/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0021
# Epoch 266/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0019
# Epoch 267/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0020
# Epoch 268/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0022
# Epoch 269/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0020
# Epoch 270/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0021
# Epoch 271/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0020
# Epoch 272/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0020
# Epoch 273/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0020
# Epoch 274/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0021
# Epoch 275/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0019
# Epoch 276/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0020
# Epoch 277/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0021
# Epoch 278/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0018
# Epoch 279/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0019
# Epoch 280/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0019
# Epoch 281/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0020
# Epoch 282/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0021
# Epoch 283/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0021
# Epoch 284/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0020
# Epoch 285/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0020
# Epoch 286/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0021
# Epoch 287/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0021
# Epoch 288/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0019
# Epoch 289/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0020
# Epoch 290/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0021
# Epoch 291/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0022
# Epoch 292/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0020
# Epoch 293/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0019
# Epoch 294/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0020
# Epoch 295/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0020
# Epoch 296/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0019
# Epoch 297/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0020
# Epoch 298/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0021
# Epoch 299/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0021
# Epoch 300/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0019
# Epoch 301/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0019
# Epoch 302/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0021
# Epoch 303/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0021
# Epoch 304/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0019
# Epoch 305/500
# 40/40 [==============================] - 1s 17ms/step - loss: 0.0021
# Epoch 306/500
# 40/40 [==============================] - 1s 17ms/step - loss: 0.0019
# Epoch 307/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0019
# Epoch 308/500
# 40/40 [==============================] - 1s 17ms/step - loss: 0.0020
# Epoch 309/500
# 40/40 [==============================] - 1s 17ms/step - loss: 0.0020
# Epoch 310/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0020
# Epoch 311/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0020
# Epoch 312/500
# 40/40 [==============================] - 1s 17ms/step - loss: 0.0020
# Epoch 313/500
# 40/40 [==============================] - 1s 17ms/step - loss: 0.0019
# Epoch 314/500
# 40/40 [==============================] - 1s 17ms/step - loss: 0.0020
# Epoch 315/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0020
# Epoch 316/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0020
# Epoch 317/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0019
# Epoch 318/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0020
# Epoch 319/500
# 40/40 [==============================] - 1s 17ms/step - loss: 0.0019
# Epoch 320/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0019
# Epoch 321/500
# 40/40 [==============================] - 1s 17ms/step - loss: 0.0019
# Epoch 322/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0019
# Epoch 323/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0021
# Epoch 324/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0019
# Epoch 325/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0019
# Epoch 326/500
# 40/40 [==============================] - 1s 18ms/step - loss: 0.0020
# Epoch 327/500
# 40/40 [==============================] - 1s 17ms/step - loss: 0.0019
# Epoch 328/500
# 40/40 [==============================] - 1s 17ms/step - loss: 0.0019
# Epoch 329/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0021
# Epoch 330/500
# 40/40 [==============================] - 1s 17ms/step - loss: 0.0019
# Epoch 331/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0019
# Epoch 332/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0019
# Epoch 333/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0019
# Epoch 334/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0019
# Epoch 335/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0019
# Epoch 336/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0019
# Epoch 337/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0018
# Epoch 338/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0019
# Epoch 339/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0019
# Epoch 340/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0019
# Epoch 341/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0019
# Epoch 342/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0019
# Epoch 343/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0018
# Epoch 344/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0019
# Epoch 345/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0019
# Epoch 346/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0018
# Epoch 347/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0019
# Epoch 348/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0019
# Epoch 349/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0019
# Epoch 350/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0019
# Epoch 351/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0020
# Epoch 352/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0020
# Epoch 353/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0019
# Epoch 354/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0019
# Epoch 355/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0019
# Epoch 356/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0018
# Epoch 357/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0019
# Epoch 358/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0019
# Epoch 359/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0018
# Epoch 360/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0019
# Epoch 361/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0018
# Epoch 362/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0018
# Epoch 363/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0018
# Epoch 364/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0019
# Epoch 365/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0019
# Epoch 366/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0021
# Epoch 367/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0020
# Epoch 368/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0018
# Epoch 369/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0018
# Epoch 370/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0019
# Epoch 371/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0018
# Epoch 372/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0018
# Epoch 373/500
# 40/40 [==============================] - 1s 17ms/step - loss: 0.0018
# Epoch 374/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0019
# Epoch 375/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0018
# Epoch 376/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0019
# Epoch 377/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0018
# Epoch 378/500
# 40/40 [==============================] - 1s 17ms/step - loss: 0.0019
# Epoch 379/500
# 40/40 [==============================] - 1s 18ms/step - loss: 0.0018
# Epoch 380/500
# 40/40 [==============================] - 1s 17ms/step - loss: 0.0019
# Epoch 381/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0019
# Epoch 382/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0018
# Epoch 383/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0019
# Epoch 384/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0017
# Epoch 385/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0018
# Epoch 386/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0017
# Epoch 387/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0017
# Epoch 388/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0019
# Epoch 389/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0020
# Epoch 390/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0018
# Epoch 391/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0018
# Epoch 392/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0018
# Epoch 393/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0019
# Epoch 394/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0018
# Epoch 395/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0017
# Epoch 396/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0019
# Epoch 397/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0018
# Epoch 398/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0019
# Epoch 399/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0019
# Epoch 400/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0020
# Epoch 401/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0018
# Epoch 402/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0017
# Epoch 403/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0018
# Epoch 404/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0019
# Epoch 405/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0017
# Epoch 406/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0018
# Epoch 407/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0018
# Epoch 408/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0019
# Epoch 409/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0018
# Epoch 410/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0018
# Epoch 411/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0017
# Epoch 412/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0017
# Epoch 413/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0018
# Epoch 414/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0018
# Epoch 415/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0018
# Epoch 416/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0021
# Epoch 417/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0018
# Epoch 418/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0019
# Epoch 419/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0018
# Epoch 420/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0017
# Epoch 421/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0018
# Epoch 422/500
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0018
# Epoch 423/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0018
# Epoch 424/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0019
# Epoch 425/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0018
# Epoch 426/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0019
# Epoch 427/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0018
# Epoch 428/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0018
# Epoch 429/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0019
# Epoch 430/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0017
# Epoch 431/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0017
# Epoch 432/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0017
# Epoch 433/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0019
# Epoch 434/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0018
# Epoch 435/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0019
# Epoch 436/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0017
# Epoch 437/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0018
# Epoch 438/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0018
# Epoch 439/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0018
# Epoch 440/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0017
# Epoch 441/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0018
# Epoch 442/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0017
# Epoch 443/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0017
# Epoch 444/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0018
# Epoch 445/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0017
# Epoch 446/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0019
# Epoch 447/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0018
# Epoch 448/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0017
# Epoch 449/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0017
# Epoch 450/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0017
# Epoch 451/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0017
# Epoch 452/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0018
# Epoch 453/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0017
# Epoch 454/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0018
# Epoch 455/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0018
# Epoch 456/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0019
# Epoch 457/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0017
# Epoch 458/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0018
# Epoch 459/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0018
# Epoch 460/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0020
# Epoch 461/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0017
# Epoch 462/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0018
# Epoch 463/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0018
# Epoch 464/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0018
# Epoch 465/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0018
# Epoch 466/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0018
# Epoch 467/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0018
# Epoch 468/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0018
# Epoch 469/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0018
# Epoch 470/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0019
# Epoch 471/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0017
# Epoch 472/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0018
# Epoch 473/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0017
# Epoch 474/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0018
# Epoch 475/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0017
# Epoch 476/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0018
# Epoch 477/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0017
# Epoch 478/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0018
# Epoch 479/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0018
# Epoch 480/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0018
# Epoch 481/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0019
# Epoch 482/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0018
# Epoch 483/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0018
# Epoch 484/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0017
# Epoch 485/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0017
# Epoch 486/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0017
# Epoch 487/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0017
# Epoch 488/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0017
# Epoch 489/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0017
# Epoch 490/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0017
# Epoch 491/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0018
# Epoch 492/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0018
# Epoch 493/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0017
# Epoch 494/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0017
# Epoch 495/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0017
# Epoch 496/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0017
# Epoch 497/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0017
# Epoch 498/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0017
# Epoch 499/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0018
# Epoch 500/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0019
# 5/5 [==============================] - 1s 8ms/step - loss: 6.4033e-04
# Test loss: 0.0006403268198482692
# 1/1 [==============================] - 1s 764ms/step
#    Actual Price  Predicted Price
# 0      0.614941          0.62104
# RMSE: 0.006098597560709074
# Files saved:
# 1. Comparison table: 'xrp_comparison_table.png'
# 2. Test loss plot: 'xrp_test_loss_plot.png'
# 3. Results plot: 'xrp_price_prediction_with_marker.png'

# %% [markdown]
# only close price, validation included

# %%
import warnings
warnings.simplefilter("ignore")
import pandas as pd
import yfinance as yf
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout, BatchNormalization
from sklearn.metrics import mean_squared_error
from keras.regularizers import l2
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
import random

# Set seeds for reproducibility
np.random.seed(42)
tf.random.set_seed(42)
random.seed(42)

# Check if TensorFlow is using a GPU
if tf.config.list_physical_devices('GPU'):
    print("Using GPU for training.")
else:
    print("No GPU detected, training on CPU.")

# Step 1: Fetch Close price data for XRP
def fetch_xrp_data(start_date, end_date):
    data = yf.download('XRP-USD', start=start_date, end=end_date)
    return data[['Close']]  # Select Close price data

xrp_data = fetch_xrp_data('2020-01-01', '2024-01-01')

# Check if data was fetched successfully
if xrp_data.empty:
    raise SystemExit("Failed to fetch data. Exiting.")

xrp_data.dropna(inplace=True)  # Remove any rows with missing values

# Step 2: Preprocess data and scale features
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(xrp_data[['Close']])  # Scale only 'Close' price

# Step 3: Prepare the dataset for training and testing (time series split)
def create_dataset(data, time_step):
    X, y = [], []
    for i in range(len(data) - time_step - 1):
        X.append(data[i:(i + time_step), 0])  # Use only the 'Close' price
        y.append(data[i + time_step, 0])  # Predict 'Close' price
    return np.array(X), np.array(y)

time_step = 60
X, y = create_dataset(scaled_data, time_step)

# Reshape data for LSTM model
X = X.reshape(X.shape[0], X.shape[1], 1)  # Adjusted for single feature (Close price)

# Step 4: Split the data into training, validation, and testing sets (80% train, 10% validation, 10% test)
train_size = int(len(X) * 0.8)
val_size = int(len(X) * 0.1)
test_size = len(X) - train_size - val_size

X_train, X_val, X_test = X[:train_size], X[train_size:train_size + val_size], X[train_size + val_size:]
y_train, y_val, y_test = y[:train_size], y[train_size:train_size + val_size], y[train_size + val_size:]

print(f"Training data shape: {X_train.shape}, {y_train.shape}")
print(f"Validation data shape: {X_val.shape}, {y_val.shape}")
print(f"Test data shape: {X_test.shape}, {y_test.shape}")

# Step 5: Build and compile the LSTM model
def build_lstm_model(input_shape):
    model = Sequential()
    model.add(LSTM(units=150, return_sequences=True, input_shape=input_shape, kernel_regularizer=l2(0.001)))
    model.add(Dropout(0.3))
    model.add(BatchNormalization())
    model.add(LSTM(units=150, return_sequences=False, kernel_regularizer=l2(0.001)))
    model.add(Dropout(0.3))
    model.add(Dense(units=100, activation='relu', kernel_regularizer=l2(0.001)))
    model.add(Dense(units=1))  # Predict the 'Close' price
    return model

model = build_lstm_model((X_train.shape[1], X_train.shape[2]))
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001), loss='mean_squared_error')

# Step 6: Define callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6)

# Step 7: Train the model with validation data and callbacks
history = model.fit(X_train, y_train, epochs=500, batch_size=32, validation_data=(X_val, y_val),
                    callbacks=[early_stopping, reduce_lr], verbose=1)

# Step 8: Evaluate the model on the test set
test_loss = model.evaluate(X_test, y_test)
print(f"Test loss: {test_loss}")

# Step 9: Prepare test data and make predictions
def make_predictions(model, data, time_step, scaler):
    test_data = data[-time_step:]  # Use the last time_step rows for testing
    X_test = test_data.reshape(1, time_step, 1)  # Adjust shape for prediction

    # Make prediction
    predicted_price = model.predict(X_test)
    predicted_price_rescaled = scaler.inverse_transform([[predicted_price[0][0]]])[0][0]  # Rescale predicted price
    return predicted_price_rescaled

predicted_price_rescaled = make_predictions(model, scaled_data, time_step, scaler)

# Step 10: Get actual price and create a comparison DataFrame
actual_price = xrp_data['Close'][-1]  # Last actual price

comparison_df = pd.DataFrame({
    'Actual Price': [actual_price],  # Single actual price
    'Predicted Price': [predicted_price_rescaled]
})

# Display the comparison DataFrame
print(comparison_df)

# Step 11: Calculate RMSE for the prediction
rmse = np.sqrt(mean_squared_error([actual_price], [predicted_price_rescaled]))
print(f"RMSE: {rmse}")

# Save the comparison to a CSV file
comparison_df.to_csv('actual_vs_predicted_xrp_v2.csv', index=False)

# Save table as PNG image
def save_table_as_image(data, filename, title):
    fig, ax = plt.subplots(figsize=(8, 2.5))
    ax.set_title(title, fontsize=12, fontweight='bold', pad=10)
    ax.axis('off')
    tbl = ax.table(cellText=data.values, colLabels=data.columns, cellLoc='center', loc='center')
    tbl.auto_set_font_size(False)
    tbl.set_fontsize(10)
    tbl.scale(1.2, 1.2)
    plt.savefig(filename, bbox_inches='tight', dpi=300)
    plt.close()

save_table_as_image(comparison_df, 'xrp_comparison_table_v2.png', 'XRP (XRP) Comparison: Actual vs Predicted Prices')

# Save test loss plot as PNG image
def save_test_loss_plot(history, filename, title, test_loss):
    plt.figure(figsize=(10, 6))
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title(f"{title} (Test Loss: {test_loss:.4f})", fontsize=12, fontweight='bold')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)
    plt.savefig(filename, bbox_inches='tight', dpi=300)
    plt.close()

save_test_loss_plot(history, 'xrp_test_loss_plot_v2.png', 'XRP (XRP) Training and Validation Loss Over Epochs', test_loss)

# Plot and save the prediction results
plt.figure(figsize=(12, 6))
plt.plot(xrp_data.index, xrp_data['Close'], label='Actual Price', color='blue')  # Actual price
plt.scatter(xrp_data.index[-1], predicted_price_rescaled, color='red', label='Predicted Price', marker='x', s=100)  # Predicted price
plt.title(f'XRP (XRP) Price Prediction: Actual vs Predicted (RMSE: {rmse:.4f})', fontsize=14, fontweight='bold', pad=15)
plt.xlabel('Date', fontsize=12, labelpad=10)
plt.ylabel('Price (USD)', fontsize=12, labelpad=10)
plt.grid(visible=True, linestyle='--', alpha=0.6)
plt.legend(fontsize=12)
plt.savefig('xrp_price_prediction_with_marker_v2.png', bbox_inches='tight', dpi=300)
plt.show()

# Inform user of saved files
print("Files saved:")
print("1. Comparison table: 'xrp_comparison_table_v2.png'")
print("2. Test loss plot: 'xrp_test_loss_plot_v2.png'")
print("3. Results plot: 'xrp_price_prediction_with_marker_v2.png'")
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Using GPU for training.
# Training data shape: (1120, 60, 1), (1120,)
# Validation data shape: (140, 60, 1), (140,)
# Test data shape: (140, 60, 1), (140,)
# Epoch 1/500
# 35/35 [==============================] - 4s 43ms/step - loss: 0.3754 - val_loss: 0.3913 - lr: 1.0000e-04
# Epoch 2/500
# 35/35 [==============================] - 1s 18ms/step - loss: 0.3539 - val_loss: 0.3709 - lr: 1.0000e-04
# Epoch 3/500
# 35/35 [==============================] - 1s 17ms/step - loss: 0.3367 - val_loss: 0.3512 - lr: 1.0000e-04
# Epoch 4/500
# 35/35 [==============================] - 1s 16ms/step - loss: 0.3207 - val_loss: 0.3322 - lr: 1.0000e-04
# Epoch 5/500
# 35/35 [==============================] - 1s 17ms/step - loss: 0.3044 - val_loss: 0.3149 - lr: 1.0000e-04
# Epoch 6/500
# 35/35 [==============================] - 1s 16ms/step - loss: 0.2910 - val_loss: 0.3015 - lr: 1.0000e-04
# Epoch 7/500
# 35/35 [==============================] - 1s 16ms/step - loss: 0.2769 - val_loss: 0.2852 - lr: 1.0000e-04
# Epoch 8/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.2633 - val_loss: 0.2698 - lr: 1.0000e-04
# Epoch 9/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.2506 - val_loss: 0.2562 - lr: 1.0000e-04
# Epoch 10/500
# 35/35 [==============================] - 1s 16ms/step - loss: 0.2388 - val_loss: 0.2452 - lr: 1.0000e-04
# Epoch 11/500
# 35/35 [==============================] - 1s 16ms/step - loss: 0.2271 - val_loss: 0.2322 - lr: 1.0000e-04
# Epoch 12/500
# 35/35 [==============================] - 1s 16ms/step - loss: 0.2162 - val_loss: 0.2190 - lr: 1.0000e-04
# Epoch 13/500
# 35/35 [==============================] - 1s 16ms/step - loss: 0.2056 - val_loss: 0.2100 - lr: 1.0000e-04
# Epoch 14/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.1963 - val_loss: 0.2002 - lr: 1.0000e-04
# Epoch 15/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.1866 - val_loss: 0.1892 - lr: 1.0000e-04
# Epoch 16/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.1779 - val_loss: 0.1778 - lr: 1.0000e-04
# Epoch 17/500
# 35/35 [==============================] - 1s 16ms/step - loss: 0.1694 - val_loss: 0.1684 - lr: 1.0000e-04
# Epoch 18/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.1618 - val_loss: 0.1591 - lr: 1.0000e-04
# Epoch 19/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.1542 - val_loss: 0.1535 - lr: 1.0000e-04
# Epoch 20/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.1472 - val_loss: 0.1451 - lr: 1.0000e-04
# Epoch 21/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.1402 - val_loss: 0.1381 - lr: 1.0000e-04
# Epoch 22/500
# 35/35 [==============================] - 1s 16ms/step - loss: 0.1340 - val_loss: 0.1334 - lr: 1.0000e-04
# Epoch 23/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.1285 - val_loss: 0.1255 - lr: 1.0000e-04
# Epoch 24/500
# 35/35 [==============================] - 1s 16ms/step - loss: 0.1229 - val_loss: 0.1200 - lr: 1.0000e-04
# Epoch 25/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.1179 - val_loss: 0.1127 - lr: 1.0000e-04
# Epoch 26/500
# 35/35 [==============================] - 1s 16ms/step - loss: 0.1121 - val_loss: 0.1089 - lr: 1.0000e-04
# Epoch 27/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.1074 - val_loss: 0.1043 - lr: 1.0000e-04
# Epoch 28/500
# 35/35 [==============================] - 1s 16ms/step - loss: 0.1032 - val_loss: 0.1018 - lr: 1.0000e-04
# Epoch 29/500
# 35/35 [==============================] - 1s 16ms/step - loss: 0.0993 - val_loss: 0.0985 - lr: 1.0000e-04
# Epoch 30/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0947 - val_loss: 0.0921 - lr: 1.0000e-04
# Epoch 31/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0908 - val_loss: 0.0877 - lr: 1.0000e-04
# Epoch 32/500
# 35/35 [==============================] - 1s 16ms/step - loss: 0.0872 - val_loss: 0.0860 - lr: 1.0000e-04
# Epoch 33/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0835 - val_loss: 0.0835 - lr: 1.0000e-04
# Epoch 34/500
# 35/35 [==============================] - 1s 16ms/step - loss: 0.0804 - val_loss: 0.0781 - lr: 1.0000e-04
# Epoch 35/500
# 35/35 [==============================] - 1s 16ms/step - loss: 0.0775 - val_loss: 0.0754 - lr: 1.0000e-04
# Epoch 36/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0745 - val_loss: 0.0714 - lr: 1.0000e-04
# Epoch 37/500
# 35/35 [==============================] - 1s 16ms/step - loss: 0.0713 - val_loss: 0.0689 - lr: 1.0000e-04
# Epoch 38/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0687 - val_loss: 0.0664 - lr: 1.0000e-04
# Epoch 39/500
# 35/35 [==============================] - 1s 16ms/step - loss: 0.0662 - val_loss: 0.0639 - lr: 1.0000e-04
# Epoch 40/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0640 - val_loss: 0.0604 - lr: 1.0000e-04
# Epoch 41/500
# 35/35 [==============================] - 1s 16ms/step - loss: 0.0614 - val_loss: 0.0585 - lr: 1.0000e-04
# Epoch 42/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0594 - val_loss: 0.0564 - lr: 1.0000e-04
# Epoch 43/500
# 35/35 [==============================] - 1s 16ms/step - loss: 0.0573 - val_loss: 0.0550 - lr: 1.0000e-04
# Epoch 44/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0552 - val_loss: 0.0528 - lr: 1.0000e-04
# Epoch 45/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0533 - val_loss: 0.0511 - lr: 1.0000e-04
# Epoch 46/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0510 - val_loss: 0.0490 - lr: 1.0000e-04
# Epoch 47/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0497 - val_loss: 0.0477 - lr: 1.0000e-04
# Epoch 48/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0477 - val_loss: 0.0457 - lr: 1.0000e-04
# Epoch 49/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0463 - val_loss: 0.0445 - lr: 1.0000e-04
# Epoch 50/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0445 - val_loss: 0.0424 - lr: 1.0000e-04
# Epoch 51/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0434 - val_loss: 0.0405 - lr: 1.0000e-04
# Epoch 52/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0418 - val_loss: 0.0394 - lr: 1.0000e-04
# Epoch 53/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0406 - val_loss: 0.0388 - lr: 1.0000e-04
# Epoch 54/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0390 - val_loss: 0.0369 - lr: 1.0000e-04
# Epoch 55/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0381 - val_loss: 0.0359 - lr: 1.0000e-04
# Epoch 56/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0365 - val_loss: 0.0344 - lr: 1.0000e-04
# Epoch 57/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0356 - val_loss: 0.0334 - lr: 1.0000e-04
# Epoch 58/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0345 - val_loss: 0.0323 - lr: 1.0000e-04
# Epoch 59/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0329 - val_loss: 0.0309 - lr: 1.0000e-04
# Epoch 60/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0323 - val_loss: 0.0298 - lr: 1.0000e-04
# Epoch 61/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0308 - val_loss: 0.0290 - lr: 1.0000e-04
# Epoch 62/500
# 35/35 [==============================] - 1s 16ms/step - loss: 0.0299 - val_loss: 0.0278 - lr: 1.0000e-04
# Epoch 63/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0291 - val_loss: 0.0269 - lr: 1.0000e-04
# Epoch 64/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0286 - val_loss: 0.0260 - lr: 1.0000e-04
# Epoch 65/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0272 - val_loss: 0.0252 - lr: 1.0000e-04
# Epoch 66/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0263 - val_loss: 0.0247 - lr: 1.0000e-04
# Epoch 67/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0261 - val_loss: 0.0236 - lr: 1.0000e-04
# Epoch 68/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0256 - val_loss: 0.0229 - lr: 1.0000e-04
# Epoch 69/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0245 - val_loss: 0.0222 - lr: 1.0000e-04
# Epoch 70/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0234 - val_loss: 0.0214 - lr: 1.0000e-04
# Epoch 71/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0228 - val_loss: 0.0210 - lr: 1.0000e-04
# Epoch 72/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0222 - val_loss: 0.0200 - lr: 1.0000e-04
# Epoch 73/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0217 - val_loss: 0.0196 - lr: 1.0000e-04
# Epoch 74/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0209 - val_loss: 0.0190 - lr: 1.0000e-04
# Epoch 75/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0201 - val_loss: 0.0184 - lr: 1.0000e-04
# Epoch 76/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0194 - val_loss: 0.0177 - lr: 1.0000e-04
# Epoch 77/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0191 - val_loss: 0.0176 - lr: 1.0000e-04
# Epoch 78/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0183 - val_loss: 0.0167 - lr: 1.0000e-04
# Epoch 79/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0183 - val_loss: 0.0165 - lr: 1.0000e-04
# Epoch 80/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0171 - val_loss: 0.0157 - lr: 1.0000e-04
# Epoch 81/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0170 - val_loss: 0.0155 - lr: 1.0000e-04
# Epoch 82/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0168 - val_loss: 0.0147 - lr: 1.0000e-04
# Epoch 83/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0164 - val_loss: 0.0145 - lr: 1.0000e-04
# Epoch 84/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0161 - val_loss: 0.0142 - lr: 1.0000e-04
# Epoch 85/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0152 - val_loss: 0.0132 - lr: 1.0000e-04
# Epoch 86/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0149 - val_loss: 0.0129 - lr: 1.0000e-04
# Epoch 87/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0142 - val_loss: 0.0125 - lr: 1.0000e-04
# Epoch 88/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0143 - val_loss: 0.0122 - lr: 1.0000e-04
# Epoch 89/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0134 - val_loss: 0.0117 - lr: 1.0000e-04
# Epoch 90/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0133 - val_loss: 0.0114 - lr: 1.0000e-04
# Epoch 91/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0126 - val_loss: 0.0111 - lr: 1.0000e-04
# Epoch 92/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0126 - val_loss: 0.0109 - lr: 1.0000e-04
# Epoch 93/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0118 - val_loss: 0.0105 - lr: 1.0000e-04
# Epoch 94/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0120 - val_loss: 0.0101 - lr: 1.0000e-04
# Epoch 95/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0111 - val_loss: 0.0099 - lr: 1.0000e-04
# Epoch 96/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0111 - val_loss: 0.0094 - lr: 1.0000e-04
# Epoch 97/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0110 - val_loss: 0.0091 - lr: 1.0000e-04
# Epoch 98/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0106 - val_loss: 0.0089 - lr: 1.0000e-04
# Epoch 99/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0105 - val_loss: 0.0086 - lr: 1.0000e-04
# Epoch 100/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0097 - val_loss: 0.0083 - lr: 1.0000e-04
# Epoch 101/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0098 - val_loss: 0.0082 - lr: 1.0000e-04
# Epoch 102/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0097 - val_loss: 0.0083 - lr: 1.0000e-04
# Epoch 103/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0096 - val_loss: 0.0077 - lr: 1.0000e-04
# Epoch 104/500
# 35/35 [==============================] - 1s 18ms/step - loss: 0.0090 - val_loss: 0.0074 - lr: 1.0000e-04
# Epoch 105/500
# 35/35 [==============================] - 1s 17ms/step - loss: 0.0091 - val_loss: 0.0074 - lr: 1.0000e-04
# Epoch 106/500
# 35/35 [==============================] - 1s 17ms/step - loss: 0.0086 - val_loss: 0.0070 - lr: 1.0000e-04
# Epoch 107/500
# 35/35 [==============================] - 1s 17ms/step - loss: 0.0085 - val_loss: 0.0070 - lr: 1.0000e-04
# Epoch 108/500
# 35/35 [==============================] - 1s 17ms/step - loss: 0.0083 - val_loss: 0.0066 - lr: 1.0000e-04
# Epoch 109/500
# 35/35 [==============================] - 1s 17ms/step - loss: 0.0081 - val_loss: 0.0064 - lr: 1.0000e-04
# Epoch 110/500
# 35/35 [==============================] - 1s 16ms/step - loss: 0.0078 - val_loss: 0.0062 - lr: 1.0000e-04
# Epoch 111/500
# 35/35 [==============================] - 1s 16ms/step - loss: 0.0078 - val_loss: 0.0061 - lr: 1.0000e-04
# Epoch 112/500
# 35/35 [==============================] - 1s 17ms/step - loss: 0.0076 - val_loss: 0.0059 - lr: 1.0000e-04
# Epoch 113/500
# 35/35 [==============================] - 1s 16ms/step - loss: 0.0073 - val_loss: 0.0058 - lr: 1.0000e-04
# Epoch 114/500
# 35/35 [==============================] - 1s 17ms/step - loss: 0.0073 - val_loss: 0.0056 - lr: 1.0000e-04
# Epoch 115/500
# 35/35 [==============================] - 1s 16ms/step - loss: 0.0071 - val_loss: 0.0056 - lr: 1.0000e-04
# Epoch 116/500
# 35/35 [==============================] - 1s 17ms/step - loss: 0.0074 - val_loss: 0.0053 - lr: 1.0000e-04
# Epoch 117/500
# 35/35 [==============================] - 1s 17ms/step - loss: 0.0072 - val_loss: 0.0055 - lr: 1.0000e-04
# Epoch 118/500
# 35/35 [==============================] - 1s 17ms/step - loss: 0.0069 - val_loss: 0.0052 - lr: 1.0000e-04
# Epoch 119/500
# 35/35 [==============================] - 1s 17ms/step - loss: 0.0064 - val_loss: 0.0049 - lr: 1.0000e-04
# Epoch 120/500
# 35/35 [==============================] - 1s 17ms/step - loss: 0.0064 - val_loss: 0.0048 - lr: 1.0000e-04
# Epoch 121/500
# 35/35 [==============================] - 1s 17ms/step - loss: 0.0066 - val_loss: 0.0053 - lr: 1.0000e-04
# Epoch 122/500
# 35/35 [==============================] - 1s 16ms/step - loss: 0.0063 - val_loss: 0.0048 - lr: 1.0000e-04
# Epoch 123/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0061 - val_loss: 0.0044 - lr: 1.0000e-04
# Epoch 124/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0061 - val_loss: 0.0044 - lr: 1.0000e-04
# Epoch 125/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0061 - val_loss: 0.0045 - lr: 1.0000e-04
# Epoch 126/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0057 - val_loss: 0.0043 - lr: 1.0000e-04
# Epoch 127/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0055 - val_loss: 0.0044 - lr: 1.0000e-04
# Epoch 128/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0053 - val_loss: 0.0041 - lr: 1.0000e-04
# Epoch 129/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0055 - val_loss: 0.0042 - lr: 1.0000e-04
# Epoch 130/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0054 - val_loss: 0.0038 - lr: 1.0000e-04
# Epoch 131/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0051 - val_loss: 0.0044 - lr: 1.0000e-04
# Epoch 132/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0054 - val_loss: 0.0036 - lr: 1.0000e-04
# Epoch 133/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0050 - val_loss: 0.0038 - lr: 1.0000e-04
# Epoch 134/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0051 - val_loss: 0.0039 - lr: 1.0000e-04
# Epoch 135/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0050 - val_loss: 0.0034 - lr: 1.0000e-04
# Epoch 136/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0050 - val_loss: 0.0036 - lr: 1.0000e-04
# Epoch 137/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0050 - val_loss: 0.0032 - lr: 1.0000e-04
# Epoch 138/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0048 - val_loss: 0.0036 - lr: 1.0000e-04
# Epoch 139/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0047 - val_loss: 0.0033 - lr: 1.0000e-04
# Epoch 140/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0044 - val_loss: 0.0031 - lr: 1.0000e-04
# Epoch 141/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0045 - val_loss: 0.0031 - lr: 1.0000e-04
# Epoch 142/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0044 - val_loss: 0.0041 - lr: 1.0000e-04
# Epoch 143/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0046 - val_loss: 0.0031 - lr: 1.0000e-04
# Epoch 144/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0042 - val_loss: 0.0034 - lr: 1.0000e-04
# Epoch 145/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0044 - val_loss: 0.0029 - lr: 1.0000e-04
# Epoch 146/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0042 - val_loss: 0.0029 - lr: 1.0000e-04
# Epoch 147/500
# 35/35 [==============================] - 1s 16ms/step - loss: 0.0044 - val_loss: 0.0031 - lr: 1.0000e-04
# Epoch 148/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0042 - val_loss: 0.0036 - lr: 1.0000e-04
# Epoch 149/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0039 - val_loss: 0.0028 - lr: 1.0000e-04
# Epoch 150/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0042 - val_loss: 0.0027 - lr: 1.0000e-04
# Epoch 151/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0040 - val_loss: 0.0027 - lr: 1.0000e-04
# Epoch 152/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0038 - val_loss: 0.0027 - lr: 1.0000e-04
# Epoch 153/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0041 - val_loss: 0.0037 - lr: 1.0000e-04
# Epoch 154/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0041 - val_loss: 0.0025 - lr: 1.0000e-04
# Epoch 155/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0044 - val_loss: 0.0024 - lr: 1.0000e-04
# Epoch 156/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0037 - val_loss: 0.0026 - lr: 1.0000e-04
# Epoch 157/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0038 - val_loss: 0.0029 - lr: 1.0000e-04
# Epoch 158/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0039 - val_loss: 0.0024 - lr: 1.0000e-04
# Epoch 159/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0038 - val_loss: 0.0025 - lr: 1.0000e-04
# Epoch 160/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0035 - val_loss: 0.0025 - lr: 1.0000e-04
# Epoch 161/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0037 - val_loss: 0.0022 - lr: 1.0000e-04
# Epoch 162/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0035 - val_loss: 0.0023 - lr: 1.0000e-04
# Epoch 163/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0041 - val_loss: 0.0026 - lr: 1.0000e-04
# Epoch 164/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0035 - val_loss: 0.0024 - lr: 1.0000e-04
# Epoch 165/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0036 - val_loss: 0.0026 - lr: 1.0000e-04
# Epoch 166/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0035 - val_loss: 0.0024 - lr: 1.0000e-04
# Epoch 167/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0037 - val_loss: 0.0029 - lr: 5.0000e-05
# Epoch 168/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0032 - val_loss: 0.0022 - lr: 5.0000e-05
# Epoch 169/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0036 - val_loss: 0.0024 - lr: 5.0000e-05
# Epoch 170/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0035 - val_loss: 0.0020 - lr: 5.0000e-05
# Epoch 171/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0032 - val_loss: 0.0021 - lr: 5.0000e-05
# Epoch 172/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0035 - val_loss: 0.0024 - lr: 5.0000e-05
# Epoch 173/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0034 - val_loss: 0.0021 - lr: 5.0000e-05
# Epoch 174/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0034 - val_loss: 0.0022 - lr: 5.0000e-05
# Epoch 175/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0034 - val_loss: 0.0020 - lr: 5.0000e-05
# Epoch 176/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0032 - val_loss: 0.0021 - lr: 2.5000e-05
# Epoch 177/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0034 - val_loss: 0.0021 - lr: 2.5000e-05
# Epoch 178/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0032 - val_loss: 0.0021 - lr: 2.5000e-05
# Epoch 179/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0033 - val_loss: 0.0021 - lr: 2.5000e-05
# Epoch 180/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0033 - val_loss: 0.0021 - lr: 2.5000e-05
# Epoch 181/500
# 35/35 [==============================] - 1s 16ms/step - loss: 0.0031 - val_loss: 0.0021 - lr: 1.2500e-05
# Epoch 182/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0032 - val_loss: 0.0020 - lr: 1.2500e-05
# Epoch 183/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0030 - val_loss: 0.0021 - lr: 1.2500e-05
# Epoch 184/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0031 - val_loss: 0.0021 - lr: 1.2500e-05
# Epoch 185/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0032 - val_loss: 0.0021 - lr: 1.2500e-05
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0016
# Test loss: 0.0016140384832397103
# 1/1 [==============================] - 1s 717ms/step
#    Actual Price  Predicted Price
# 0      0.614941         0.628601
# RMSE: 0.013660392596609228
# Files saved:
# 1. Comparison table: 'xrp_comparison_table_v2.png'
# 2. Test loss plot: 'xrp_test_loss_plot_v2.png'
# 3. Results plot: 'xrp_price_prediction_with_marker_v2.png'

# %% [markdown]
# multiple features, no validation included

# %%
import warnings
warnings.simplefilter("ignore")
import pandas as pd
import yfinance as yf
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout, BatchNormalization
from sklearn.metrics import mean_squared_error
from keras.regularizers import l2
import random

# Set seeds for reproducibility
np.random.seed(42)
tf.random.set_seed(42)
random.seed(42)

# Check if TensorFlow is using a GPU
if tf.config.list_physical_devices('GPU'):
    print("Using GPU for training.")
else:
    print("No GPU detected, training on CPU.")

# Step 1: Fetch OHLC data for XRP
def fetch_xrp_data(start_date, end_date):
    data = yf.download('XRP-USD', start=start_date, end=end_date)
    return data[['Open', 'High', 'Low', 'Close']]  # Select OHLC data

xrp_data = fetch_xrp_data('2020-01-01', '2024-01-01')

# Check if data was fetched successfully
if xrp_data.empty:
    raise SystemExit("Failed to fetch data. Exiting.")

xrp_data.dropna(inplace=True)  # Remove any rows with missing values

# Step 2: Preprocess data and scale features
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(xrp_data)

# Step 3: Prepare the dataset for training and testing (time series split)
def create_dataset(data, time_step):
    X, y = [], []
    for i in range(len(data) - time_step - 1):
        X.append(data[i:(i + time_step), :])  # Use OHLC data
        y.append(data[i + time_step, 3])  # Predict 'Close' price
    return np.array(X), np.array(y)

time_step = 60
X, y = create_dataset(scaled_data, time_step)

# Reshape data for LSTM model
X = X.reshape(X.shape[0], X.shape[1], X.shape[2])

# Step 4: Split the data into training and testing sets (90% train, 10% test)
train_size = int(len(X) * 0.9)  # 90-10 split
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

print(f"Training data shape: {X_train.shape}, {y_train.shape}")
print(f"Test data shape: {X_test.shape}, {y_test.shape}")

# Step 5: Build and compile the LSTM model
def build_lstm_model(input_shape):
    model = Sequential()
    model.add(LSTM(units=150, return_sequences=True, input_shape=input_shape, kernel_regularizer=l2(0.001)))
    model.add(Dropout(0.3))
    model.add(BatchNormalization())
    model.add(LSTM(units=150, return_sequences=False, kernel_regularizer=l2(0.001)))
    model.add(Dropout(0.3))
    model.add(Dense(units=100, activation='relu', kernel_regularizer=l2(0.001)))
    model.add(Dense(units=1))  # Predict the 'Close' price
    return model

model = build_lstm_model((X_train.shape[1], X_train.shape[2]))
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001), loss='mean_squared_error')

# Step 6: Train the model
history = model.fit(X_train, y_train, epochs=500, batch_size=32, verbose=1)

# Step 7: Evaluate the model on the test set
test_loss = model.evaluate(X_test, y_test)
print(f"Test loss: {test_loss}")

# Step 8: Prepare test data and make predictions
def make_predictions(model, data, time_step, scaler):
    test_data = data[-time_step:]  # Last time_step rows for testing
    X_test = test_data.reshape(1, time_step, data.shape[1])  # Adjust shape for prediction

    # Make prediction
    predicted_price = model.predict(X_test)

    # Rescale predicted price using the scaler for the 'Close' price only
    predicted_price_rescaled = scaler.inverse_transform(
        np.concatenate((np.zeros((1, 3)), predicted_price), axis=1)
    )[:, 3]  # Rescale and extract 'Close' price
    return predicted_price_rescaled[0]

predicted_price_rescaled = make_predictions(model, scaled_data, time_step, scaler)

# Step 9: Get actual price and create a comparison DataFrame
actual_price = xrp_data['Close'][-1]  # Last actual price

comparison_df = pd.DataFrame({
    'Actual Price': [actual_price],  # Single actual price
    'Predicted Price': [predicted_price_rescaled]
})

# Display the comparison DataFrame
print(comparison_df)

# Step 10: Calculate RMSE for the prediction
rmse = np.sqrt(mean_squared_error([actual_price], [predicted_price_rescaled]))
print(f"RMSE: {rmse}")

# Save the comparison to a CSV file
comparison_df.to_csv('xrp_actual_vs_predicted_multiple_features.csv', index=False)

# Save table as PNG image
def save_table_as_image(data, filename, title):
    fig, ax = plt.subplots(figsize=(8, 2.5))
    ax.set_title(title, fontsize=12, fontweight='bold', pad=10)
    ax.axis('off')
    tbl = ax.table(cellText=data.values, colLabels=data.columns, cellLoc='center', loc='center')
    tbl.auto_set_font_size(False)
    tbl.set_fontsize(10)
    tbl.scale(1.2, 1.2)
    plt.savefig(filename, bbox_inches='tight', dpi=300)
    plt.close()

save_table_as_image(comparison_df, 'xrp_comparison_table_multiple_features.png', 'XRP (XRP) Actual vs Predicted Prices')

# Save test loss plot as PNG image
def save_test_loss_plot(history, filename, title, test_loss):
    plt.figure(figsize=(10, 6))
    plt.plot(history.history['loss'], label='Training Loss')
    plt.title(f"{title} (Test Loss: {test_loss:.4f})", fontsize=12, fontweight='bold')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)
    plt.savefig(filename, bbox_inches='tight', dpi=300)
    plt.close()

save_test_loss_plot(history, 'xrp_test_loss_plot_multiple_features.png', 'XRP (XRP) Training Loss Over Epochs', test_loss)

# Plot and save the prediction results
plt.figure(figsize=(12, 6))
plt.plot(xrp_data['Close'], label='Actual Price', color='blue')  # Actual price
plt.scatter(xrp_data.index[-1], predicted_price_rescaled, color='red', label='Predicted Price', marker='x', s=100)  # Predicted price
plt.title(f'XRP (XRP) Price Prediction (Multiple Features): Actual vs Predicted (RMSE: {rmse:.4f})', fontsize=14, fontweight='bold', pad=15)
plt.xlabel('Date')
plt.ylabel('Price (USD)')
plt.grid(visible=True, linestyle='--', alpha=0.6)
plt.legend()
plt.savefig('xrp_price_prediction_multiple_features.png', bbox_inches='tight', dpi=300)
plt.show()

# Inform user of saved files
print("Files saved:")
print("1. Comparison table: 'xrp_comparison_table_multiple_features.png'")
print("2. Test loss plot: 'xrp_test_loss_plot_multiple_features.png'")
print("3. Results plot: 'xrp_price_prediction_multiple_features.png'")
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Using GPU for training.
# Training data shape: (1260, 60, 4), (1260,)
# Test data shape: (140, 60, 4), (140,)
# Epoch 1/500
# 40/40 [==============================] - 4s 17ms/step - loss: 0.3862
# Epoch 2/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.3645
# Epoch 3/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.3485
# Epoch 4/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.3328
# Epoch 5/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.3169
# Epoch 6/500
# 40/40 [==============================] - 1s 17ms/step - loss: 0.3027
# Epoch 7/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.2905
# Epoch 8/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.2759
# Epoch 9/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.2637
# Epoch 10/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.2520
# Epoch 11/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.2401
# Epoch 12/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.2291
# Epoch 13/500
# 40/40 [==============================] - 1s 17ms/step - loss: 0.2184
# Epoch 14/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.2084
# Epoch 15/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.1990
# Epoch 16/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.1899
# Epoch 17/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.1810
# Epoch 18/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.1730
# Epoch 19/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.1654
# Epoch 20/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.1585
# Epoch 21/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.1508
# Epoch 22/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.1442
# Epoch 23/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.1380
# Epoch 24/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.1321
# Epoch 25/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.1264
# Epoch 26/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.1210
# Epoch 27/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.1158
# Epoch 28/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.1108
# Epoch 29/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.1067
# Epoch 30/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.1022
# Epoch 31/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0977
# Epoch 32/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0939
# Epoch 33/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0897
# Epoch 34/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0866
# Epoch 35/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0825
# Epoch 36/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0794
# Epoch 37/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0763
# Epoch 38/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0735
# Epoch 39/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0707
# Epoch 40/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0680
# Epoch 41/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0655
# Epoch 42/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0631
# Epoch 43/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0605
# Epoch 44/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0587
# Epoch 45/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0561
# Epoch 46/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0543
# Epoch 47/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0521
# Epoch 48/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0503
# Epoch 49/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0486
# Epoch 50/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0467
# Epoch 51/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0455
# Epoch 52/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0439
# Epoch 53/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0427
# Epoch 54/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0408
# Epoch 55/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0391
# Epoch 56/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0381
# Epoch 57/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0367
# Epoch 58/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0353
# Epoch 59/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0344
# Epoch 60/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0335
# Epoch 61/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0319
# Epoch 62/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0313
# Epoch 63/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0301
# Epoch 64/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0291
# Epoch 65/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0282
# Epoch 66/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0272
# Epoch 67/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0265
# Epoch 68/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0254
# Epoch 69/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0249
# Epoch 70/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0243
# Epoch 71/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0230
# Epoch 72/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0224
# Epoch 73/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0220
# Epoch 74/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0212
# Epoch 75/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0205
# Epoch 76/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0202
# Epoch 77/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0192
# Epoch 78/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0188
# Epoch 79/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0182
# Epoch 80/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0179
# Epoch 81/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0170
# Epoch 82/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0171
# Epoch 83/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0161
# Epoch 84/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0156
# Epoch 85/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0152
# Epoch 86/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0149
# Epoch 87/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0142
# Epoch 88/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0140
# Epoch 89/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0137
# Epoch 90/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0135
# Epoch 91/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0130
# Epoch 92/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0127
# Epoch 93/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0124
# Epoch 94/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0118
# Epoch 95/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0116
# Epoch 96/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0113
# Epoch 97/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0112
# Epoch 98/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0110
# Epoch 99/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0104
# Epoch 100/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0105
# Epoch 101/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0102
# Epoch 102/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0100
# Epoch 103/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0097
# Epoch 104/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0093
# Epoch 105/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0090
# Epoch 106/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0090
# Epoch 107/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0086
# Epoch 108/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0084
# Epoch 109/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0084
# Epoch 110/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0080
# Epoch 111/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0080
# Epoch 112/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0078
# Epoch 113/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0075
# Epoch 114/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0077
# Epoch 115/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0072
# Epoch 116/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0073
# Epoch 117/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0070
# Epoch 118/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0068
# Epoch 119/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0065
# Epoch 120/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0064
# Epoch 121/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0063
# Epoch 122/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0063
# Epoch 123/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0062
# Epoch 124/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0060
# Epoch 125/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0057
# Epoch 126/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0058
# Epoch 127/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0058
# Epoch 128/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0055
# Epoch 129/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0058
# Epoch 130/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0055
# Epoch 131/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0053
# Epoch 132/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0055
# Epoch 133/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0050
# Epoch 134/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0054
# Epoch 135/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0049
# Epoch 136/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0053
# Epoch 137/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0049
# Epoch 138/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0051
# Epoch 139/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0048
# Epoch 140/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0049
# Epoch 141/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0044
# Epoch 142/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0048
# Epoch 143/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0045
# Epoch 144/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0046
# Epoch 145/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0047
# Epoch 146/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0043
# Epoch 147/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0044
# Epoch 148/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0042
# Epoch 149/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0042
# Epoch 150/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0042
# Epoch 151/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0042
# Epoch 152/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0043
# Epoch 153/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0040
# Epoch 154/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0041
# Epoch 155/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0043
# Epoch 156/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0043
# Epoch 157/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0040
# Epoch 158/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0036
# Epoch 159/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0042
# Epoch 160/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0039
# Epoch 161/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0037
# Epoch 162/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0036
# Epoch 163/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0035
# Epoch 164/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0035
# Epoch 165/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0035
# Epoch 166/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0038
# Epoch 167/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0034
# Epoch 168/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0038
# Epoch 169/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0037
# Epoch 170/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0036
# Epoch 171/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0039
# Epoch 172/500
# 40/40 [==============================] - 1s 17ms/step - loss: 0.0036
# Epoch 173/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0032
# Epoch 174/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0035
# Epoch 175/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0034
# Epoch 176/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0033
# Epoch 177/500
# 40/40 [==============================] - 1s 17ms/step - loss: 0.0036
# Epoch 178/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0034
# Epoch 179/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0034
# Epoch 180/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0032
# Epoch 181/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0034
# Epoch 182/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0034
# Epoch 183/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0033
# Epoch 184/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0032
# Epoch 185/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0032
# Epoch 186/500
# 40/40 [==============================] - 1s 17ms/step - loss: 0.0032
# Epoch 187/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0032
# Epoch 188/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0032
# Epoch 189/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0031
# Epoch 190/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0031
# Epoch 191/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0032
# Epoch 192/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0030
# Epoch 193/500
# 40/40 [==============================] - 1s 19ms/step - loss: 0.0031
# Epoch 194/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0033
# Epoch 195/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0030
# Epoch 196/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0030
# Epoch 197/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0030
# Epoch 198/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0030
# Epoch 199/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0030
# Epoch 200/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0031
# Epoch 201/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0029
# Epoch 202/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0029
# Epoch 203/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0028
# Epoch 204/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0028
# Epoch 205/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0030
# Epoch 206/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0027
# Epoch 207/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0028
# Epoch 208/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0028
# Epoch 209/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0027
# Epoch 210/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0027
# Epoch 211/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0028
# Epoch 212/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0027
# Epoch 213/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0028
# Epoch 214/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0028
# Epoch 215/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0028
# Epoch 216/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0027
# Epoch 217/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0026
# Epoch 218/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0025
# Epoch 219/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0027
# Epoch 220/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0027
# Epoch 221/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0027
# Epoch 222/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0029
# Epoch 223/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0027
# Epoch 224/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0025
# Epoch 225/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0025
# Epoch 226/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0026
# Epoch 227/500
# 40/40 [==============================] - 1s 17ms/step - loss: 0.0026
# Epoch 228/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0025
# Epoch 229/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0025
# Epoch 230/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0026
# Epoch 231/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0027
# Epoch 232/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0026
# Epoch 233/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0024
# Epoch 234/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0025
# Epoch 235/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0024
# Epoch 236/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0026
# Epoch 237/500
# 40/40 [==============================] - 1s 17ms/step - loss: 0.0028
# Epoch 238/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0024
# Epoch 239/500
# 40/40 [==============================] - 1s 17ms/step - loss: 0.0025
# Epoch 240/500
# 40/40 [==============================] - 1s 17ms/step - loss: 0.0023
# Epoch 241/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0024
# Epoch 242/500
# 40/40 [==============================] - 1s 18ms/step - loss: 0.0024
# Epoch 243/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0022
# Epoch 244/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0022
# Epoch 245/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0023
# Epoch 246/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0024
# Epoch 247/500
# 40/40 [==============================] - 1s 17ms/step - loss: 0.0025
# Epoch 248/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0024
# Epoch 249/500
# 40/40 [==============================] - 1s 17ms/step - loss: 0.0023
# Epoch 250/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0021
# Epoch 251/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0023
# Epoch 252/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0024
# Epoch 253/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0024
# Epoch 254/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0023
# Epoch 255/500
# 40/40 [==============================] - 1s 17ms/step - loss: 0.0023
# Epoch 256/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0022
# Epoch 257/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0022
# Epoch 258/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0023
# Epoch 259/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0022
# Epoch 260/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0022
# Epoch 261/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0021
# Epoch 262/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0022
# Epoch 263/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0023
# Epoch 264/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0022
# Epoch 265/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0022
# Epoch 266/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0021
# Epoch 267/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0022
# Epoch 268/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0022
# Epoch 269/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0022
# Epoch 270/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0022
# Epoch 271/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0022
# Epoch 272/500
# 40/40 [==============================] - 1s 18ms/step - loss: 0.0023
# Epoch 273/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0021
# Epoch 274/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0023
# Epoch 275/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0021
# Epoch 276/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0021
# Epoch 277/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0023
# Epoch 278/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0020
# Epoch 279/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0021
# Epoch 280/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0022
# Epoch 281/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0021
# Epoch 282/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0022
# Epoch 283/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0022
# Epoch 284/500
# 40/40 [==============================] - 1s 17ms/step - loss: 0.0021
# Epoch 285/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0021
# Epoch 286/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0022
# Epoch 287/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0021
# Epoch 288/500
# 40/40 [==============================] - 1s 17ms/step - loss: 0.0020
# Epoch 289/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0022
# Epoch 290/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0021
# Epoch 291/500
# 40/40 [==============================] - 1s 17ms/step - loss: 0.0022
# Epoch 292/500
# 40/40 [==============================] - 1s 17ms/step - loss: 0.0022
# Epoch 293/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0020
# Epoch 294/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0021
# Epoch 295/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0021
# Epoch 296/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0020
# Epoch 297/500
# 40/40 [==============================] - 1s 17ms/step - loss: 0.0021
# Epoch 298/500
# 40/40 [==============================] - 1s 17ms/step - loss: 0.0022
# Epoch 299/500
# 40/40 [==============================] - 1s 17ms/step - loss: 0.0021
# Epoch 300/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0020
# Epoch 301/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0020
# Epoch 302/500
# 40/40 [==============================] - 1s 17ms/step - loss: 0.0021
# Epoch 303/500
# 40/40 [==============================] - 1s 17ms/step - loss: 0.0021
# Epoch 304/500
# 40/40 [==============================] - 1s 17ms/step - loss: 0.0020
# Epoch 305/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0022
# Epoch 306/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0020
# Epoch 307/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0020
# Epoch 308/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0021
# Epoch 309/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0021
# Epoch 310/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0023
# Epoch 311/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0021
# Epoch 312/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0020
# Epoch 313/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0019
# Epoch 314/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0020
# Epoch 315/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0021
# Epoch 316/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0021
# Epoch 317/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0020
# Epoch 318/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0020
# Epoch 319/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0020
# Epoch 320/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0020
# Epoch 321/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0020
# Epoch 322/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0021
# Epoch 323/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0021
# Epoch 324/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0019
# Epoch 325/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0020
# Epoch 326/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0019
# Epoch 327/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0019
# Epoch 328/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0020
# Epoch 329/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0021
# Epoch 330/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0019
# Epoch 331/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0020
# Epoch 332/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0020
# Epoch 333/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0019
# Epoch 334/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0020
# Epoch 335/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0020
# Epoch 336/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0021
# Epoch 337/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0019
# Epoch 338/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0020
# Epoch 339/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0020
# Epoch 340/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0020
# Epoch 341/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0019
# Epoch 342/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0020
# Epoch 343/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0019
# Epoch 344/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0020
# Epoch 345/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0020
# Epoch 346/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0019
# Epoch 347/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0020
# Epoch 348/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0019
# Epoch 349/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0019
# Epoch 350/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0020
# Epoch 351/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0020
# Epoch 352/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0020
# Epoch 353/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0019
# Epoch 354/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0019
# Epoch 355/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0018
# Epoch 356/500
# 40/40 [==============================] - 1s 17ms/step - loss: 0.0018
# Epoch 357/500
# 40/40 [==============================] - 1s 18ms/step - loss: 0.0019
# Epoch 358/500
# 40/40 [==============================] - 1s 17ms/step - loss: 0.0019
# Epoch 359/500
# 40/40 [==============================] - 1s 17ms/step - loss: 0.0018
# Epoch 360/500
# 40/40 [==============================] - 1s 17ms/step - loss: 0.0020
# Epoch 361/500
# 40/40 [==============================] - 1s 17ms/step - loss: 0.0018
# Epoch 362/500
# 40/40 [==============================] - 1s 17ms/step - loss: 0.0019
# Epoch 363/500
# 40/40 [==============================] - 1s 17ms/step - loss: 0.0018
# Epoch 364/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0018
# Epoch 365/500
# 40/40 [==============================] - 1s 17ms/step - loss: 0.0019
# Epoch 366/500
# 40/40 [==============================] - 1s 17ms/step - loss: 0.0020
# Epoch 367/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0022
# Epoch 368/500
# 40/40 [==============================] - 1s 17ms/step - loss: 0.0019
# Epoch 369/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0019
# Epoch 370/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0019
# Epoch 371/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0018
# Epoch 372/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0017
# Epoch 373/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0018
# Epoch 374/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0019
# Epoch 375/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0019
# Epoch 376/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0019
# Epoch 377/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0018
# Epoch 378/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0019
# Epoch 379/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0019
# Epoch 380/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0019
# Epoch 381/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0018
# Epoch 382/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0018
# Epoch 383/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0019
# Epoch 384/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0017
# Epoch 385/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0018
# Epoch 386/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0018
# Epoch 387/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0017
# Epoch 388/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0018
# Epoch 389/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0020
# Epoch 390/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0018
# Epoch 391/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0018
# Epoch 392/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0017
# Epoch 393/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0017
# Epoch 394/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0019
# Epoch 395/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0017
# Epoch 396/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0019
# Epoch 397/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0019
# Epoch 398/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0018
# Epoch 399/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0020
# Epoch 400/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0019
# Epoch 401/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0018
# Epoch 402/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0016
# Epoch 403/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0019
# Epoch 404/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0018
# Epoch 405/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0019
# Epoch 406/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0019
# Epoch 407/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0019
# Epoch 408/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0020
# Epoch 409/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0019
# Epoch 410/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0017
# Epoch 411/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0017
# Epoch 412/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0017
# Epoch 413/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0018
# Epoch 414/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0017
# Epoch 415/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0018
# Epoch 416/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0018
# Epoch 417/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0017
# Epoch 418/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0018
# Epoch 419/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0019
# Epoch 420/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0017
# Epoch 421/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0018
# Epoch 422/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0018
# Epoch 423/500
# 40/40 [==============================] - 1s 18ms/step - loss: 0.0018
# Epoch 424/500
# 40/40 [==============================] - 1s 17ms/step - loss: 0.0019
# Epoch 425/500
# 40/40 [==============================] - 1s 17ms/step - loss: 0.0018
# Epoch 426/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0019
# Epoch 427/500
# 40/40 [==============================] - 1s 18ms/step - loss: 0.0019
# Epoch 428/500
# 40/40 [==============================] - 1s 18ms/step - loss: 0.0018
# Epoch 429/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0019
# Epoch 430/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0020
# Epoch 431/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0019
# Epoch 432/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0017
# Epoch 433/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0017
# Epoch 434/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0018
# Epoch 435/500
# 40/40 [==============================] - 1s 17ms/step - loss: 0.0018
# Epoch 436/500
# 40/40 [==============================] - 1s 17ms/step - loss: 0.0017
# Epoch 437/500
# 40/40 [==============================] - 1s 17ms/step - loss: 0.0019
# Epoch 438/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0018
# Epoch 439/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0018
# Epoch 440/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0018
# Epoch 441/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0018
# Epoch 442/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0018
# Epoch 443/500
# 40/40 [==============================] - 1s 17ms/step - loss: 0.0018
# Epoch 444/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0018
# Epoch 445/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0017
# Epoch 446/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0018
# Epoch 447/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0018
# Epoch 448/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0017
# Epoch 449/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0016
# Epoch 450/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0017
# Epoch 451/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0017
# Epoch 452/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0018
# Epoch 453/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0017
# Epoch 454/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0018
# Epoch 455/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0018
# Epoch 456/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0018
# Epoch 457/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0017
# Epoch 458/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0017
# Epoch 459/500
# 40/40 [==============================] - 1s 18ms/step - loss: 0.0018
# Epoch 460/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0019
# Epoch 461/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0017
# Epoch 462/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0018
# Epoch 463/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0018
# Epoch 464/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0017
# Epoch 465/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0017
# Epoch 466/500
# 40/40 [==============================] - 1s 17ms/step - loss: 0.0017
# Epoch 467/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0018
# Epoch 468/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0018
# Epoch 469/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0018
# Epoch 470/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0019
# Epoch 471/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0017
# Epoch 472/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0017
# Epoch 473/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0016
# Epoch 474/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0018
# Epoch 475/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0015
# Epoch 476/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0018
# Epoch 477/500
# 40/40 [==============================] - 1s 17ms/step - loss: 0.0018
# Epoch 478/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0017
# Epoch 479/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0017
# Epoch 480/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0018
# Epoch 481/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0019
# Epoch 482/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0018
# Epoch 483/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0018
# Epoch 484/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0017
# Epoch 485/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0017
# Epoch 486/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0017
# Epoch 487/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0016
# Epoch 488/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0017
# Epoch 489/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0017
# Epoch 490/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0016
# Epoch 491/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0018
# Epoch 492/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0019
# Epoch 493/500
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0016
# Epoch 494/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0017
# Epoch 495/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0017
# Epoch 496/500
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0017
# Epoch 497/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0017
# Epoch 498/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0017
# Epoch 499/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0018
# Epoch 500/500
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0018
# 5/5 [==============================] - 1s 6ms/step - loss: 6.9493e-04
# Test loss: 0.0006949261878617108
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000024EF05E8790> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 1s 745ms/step
#    Actual Price  Predicted Price
# 0      0.614941         0.634804
# RMSE: 0.01986304096933722
# Files saved:
# 1. Comparison table: 'xrp_comparison_table_multiple_features.png'
# 2. Test loss plot: 'xrp_test_loss_plot_multiple_features.png'
# 3. Results plot: 'xrp_price_prediction_multiple_features.png'

# %% [markdown]
# multiple features, validation included

# %%
import warnings
warnings.simplefilter("ignore")
import pandas as pd
import yfinance as yf
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout, BatchNormalization
from sklearn.metrics import mean_squared_error
from keras.regularizers import l2
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
import random

# Set seeds for reproducibility
np.random.seed(42)
tf.random.set_seed(42)
random.seed(42)

# Check if TensorFlow is using a GPU
if tf.config.list_physical_devices('GPU'):
    print("Using GPU for training.")
else:
    print("No GPU detected, training on CPU.")

# Step 1: Fetch OHLC data for XRP
def fetch_xrp_data(start_date, end_date):
    data = yf.download('XRP-USD', start=start_date, end=end_date)
    return data[['Open', 'High', 'Low', 'Close']]  # Select OHLC data

xrp_data = fetch_xrp_data('2020-01-01', '2024-01-01')

# Check if data was fetched successfully
if xrp_data.empty:
    raise SystemExit("Failed to fetch data. Exiting.")

xrp_data.dropna(inplace=True)  # Remove any rows with missing values

# Step 2: Preprocess data and scale features
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(xrp_data)

# Step 3: Prepare the dataset for training, validation, and testing (time series split)
def create_dataset(data, time_step):
    X, y = [], []
    for i in range(len(data) - time_step - 1):
        X.append(data[i:(i + time_step), :])  # Use OHLC data
        y.append(data[i + time_step, 3])  # Predict 'Close' price
    return np.array(X), np.array(y)

time_step = 60
X, y = create_dataset(scaled_data, time_step)

# Reshape data for LSTM model
X = X.reshape(X.shape[0], X.shape[1], X.shape[2])

# Split into training (80%), validation (10%), and testing (10%)
train_size = int(len(X) * 0.8)
val_size = int(len(X) * 0.1)
X_train, X_val, X_test = X[:train_size], X[train_size:train_size + val_size], X[train_size + val_size:]
y_train, y_val, y_test = y[:train_size], y[train_size:train_size + val_size], y[train_size + val_size:]

print(f"Training data shape: {X_train.shape}, {y_train.shape}")
print(f"Validation data shape: {X_val.shape}, {y_val.shape}")
print(f"Test data shape: {X_test.shape}, {y_test.shape}")

# Step 4: Build and compile the LSTM model
def build_lstm_model(input_shape):
    model = Sequential()
    model.add(LSTM(units=150, return_sequences=True, input_shape=input_shape, kernel_regularizer=l2(0.001)))
    model.add(Dropout(0.3))
    model.add(BatchNormalization())
    model.add(LSTM(units=150, return_sequences=False, kernel_regularizer=l2(0.001)))
    model.add(Dropout(0.3))
    model.add(Dense(units=100, activation='relu', kernel_regularizer=l2(0.001)))
    model.add(Dense(units=1))  # Predict the 'Close' price
    return model

model = build_lstm_model((X_train.shape[1], X_train.shape[2]))
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001), loss='mean_squared_error')

# Step 5: Define callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6)

# Step 6: Train the model with validation data and callbacks
history = model.fit(X_train, y_train, epochs=500, batch_size=32, validation_data=(X_val, y_val),
                    callbacks=[early_stopping, reduce_lr], verbose=1)

# Step 7: Evaluate the model on the test set
test_loss = model.evaluate(X_test, y_test)
print(f"Test loss: {test_loss}")

# Step 8: Prepare test data and make predictions
def make_predictions(model, data, time_step, scaler):
    test_data = data[-time_step:]  # Last time_step rows for testing
    X_test = test_data.reshape(1, time_step, data.shape[1])  # Adjust shape for prediction

    # Make prediction
    predicted_price = model.predict(X_test)

    # Rescale predicted price using the scaler for the 'Close' price only
    predicted_price_rescaled = scaler.inverse_transform(
        np.concatenate((np.zeros((1, 3)), predicted_price), axis=1)
    )[:, 3]  # Rescale and extract 'Close' price
    return predicted_price_rescaled[0]

predicted_price_rescaled = make_predictions(model, scaled_data, time_step, scaler)

# Step 9: Get actual price and create a comparison DataFrame
actual_price = xrp_data['Close'][-1]  # Last actual price

comparison_df = pd.DataFrame({
    'Actual Price': [actual_price],  # Single actual price
    'Predicted Price': [predicted_price_rescaled]
})

# Display the comparison DataFrame
print(comparison_df)

# Step 10: Calculate RMSE for the prediction
rmse = np.sqrt(mean_squared_error([actual_price], [predicted_price_rescaled]))
print(f"RMSE: {rmse}")

# Save the comparison to a CSV file
comparison_df.to_csv('xrp_actual_vs_predicted_multiple_features_with_val_v2.csv', index=False)

# Save table as PNG image
def save_table_as_image(data, filename, title):
    fig, ax = plt.subplots(figsize=(8, 2.5))
    ax.set_title(title, fontsize=12, fontweight='bold', pad=10)
    ax.axis('off')
    tbl = ax.table(cellText=data.values.round(4), colLabels=data.columns, cellLoc='center', loc='center')
    tbl.auto_set_font_size(False)
    tbl.set_fontsize(10)
    tbl.scale(1.2, 1.2)
    plt.savefig(filename, bbox_inches='tight', dpi=300)
    plt.close()

save_table_as_image(comparison_df, 'xrp_comparison_table_multiple_features_with_val_v2.png', 'XRP (XRP) Actual vs Predicted Prices')

# Save test loss plot as PNG image
def save_test_loss_plot(history, filename, title, test_loss):
    plt.figure(figsize=(10, 6))
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title(f"{title} (Test Loss: {test_loss:.4f})", fontsize=12, fontweight='bold')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)
    plt.savefig(filename, bbox_inches='tight', dpi=300)
    plt.close()

save_test_loss_plot(history, 'xrp_test_loss_plot_multiple_features_with_val_v2.png', 'XRP (XRP) Training and Validation Loss Over Epochs', test_loss)

# Plot and save the prediction results
plt.figure(figsize=(12, 6))
plt.plot(xrp_data['Close'], label='Actual Price', color='blue')  # Actual price
plt.scatter(xrp_data.index[-1], predicted_price_rescaled, color='red', label='Predicted Price', marker='x', s=100)  # Predicted price
plt.title(f'XRP (XRP) Price Prediction (Multiple Features with Validation v2): Actual vs Predicted (RMSE: {rmse:.4f})', fontsize=14, fontweight='bold', pad=15)
plt.xlabel('Date')
plt.ylabel('Price (USD)')
plt.grid(visible=True, linestyle='--', alpha=0.6)
plt.legend()
plt.savefig('xrp_price_prediction_multiple_features_with_val_v2.png', bbox_inches='tight', dpi=300)
plt.show()

# Inform user of saved files
print("Files saved:")
print("1. Comparison table: 'xrp_comparison_table_multiple_features_with_val_v2.png'")
print("2. Test loss plot: 'xrp_test_loss_plot_multiple_features_with_val_v2.png'")
print("3. Results plot: 'xrp_price_prediction_multiple_features_with_val_v2.png'")
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Using GPU for training.
# Training data shape: (1120, 60, 4), (1120,)
# Validation data shape: (140, 60, 4), (140,)
# Test data shape: (140, 60, 4), (140,)
# Epoch 1/500
# 35/35 [==============================] - 5s 43ms/step - loss: 0.3860 - val_loss: 0.3984 - lr: 1.0000e-04
# Epoch 2/500
# 35/35 [==============================] - 1s 17ms/step - loss: 0.3670 - val_loss: 0.3867 - lr: 1.0000e-04
# Epoch 3/500
# 35/35 [==============================] - 1s 17ms/step - loss: 0.3522 - val_loss: 0.3745 - lr: 1.0000e-04
# Epoch 4/500
# 35/35 [==============================] - 1s 17ms/step - loss: 0.3369 - val_loss: 0.3577 - lr: 1.0000e-04
# Epoch 5/500
# 35/35 [==============================] - 1s 18ms/step - loss: 0.3229 - val_loss: 0.3430 - lr: 1.0000e-04
# Epoch 6/500
# 35/35 [==============================] - 1s 18ms/step - loss: 0.3101 - val_loss: 0.3310 - lr: 1.0000e-04
# Epoch 7/500
# 35/35 [==============================] - 1s 17ms/step - loss: 0.2979 - val_loss: 0.3150 - lr: 1.0000e-04
# Epoch 8/500
# 35/35 [==============================] - 1s 17ms/step - loss: 0.2862 - val_loss: 0.3011 - lr: 1.0000e-04
# Epoch 9/500
# 35/35 [==============================] - 1s 17ms/step - loss: 0.2740 - val_loss: 0.2908 - lr: 1.0000e-04
# Epoch 10/500
# 35/35 [==============================] - 1s 17ms/step - loss: 0.2620 - val_loss: 0.2772 - lr: 1.0000e-04
# Epoch 11/500
# 35/35 [==============================] - 1s 17ms/step - loss: 0.2522 - val_loss: 0.2641 - lr: 1.0000e-04
# Epoch 12/500
# 35/35 [==============================] - 1s 18ms/step - loss: 0.2418 - val_loss: 0.2548 - lr: 1.0000e-04
# Epoch 13/500
# 35/35 [==============================] - 1s 17ms/step - loss: 0.2322 - val_loss: 0.2418 - lr: 1.0000e-04
# Epoch 14/500
# 35/35 [==============================] - 1s 17ms/step - loss: 0.2229 - val_loss: 0.2338 - lr: 1.0000e-04
# Epoch 15/500
# 35/35 [==============================] - 1s 17ms/step - loss: 0.2135 - val_loss: 0.2226 - lr: 1.0000e-04
# Epoch 16/500
# 35/35 [==============================] - 1s 17ms/step - loss: 0.2051 - val_loss: 0.2092 - lr: 1.0000e-04
# Epoch 17/500
# 35/35 [==============================] - 1s 17ms/step - loss: 0.1964 - val_loss: 0.1975 - lr: 1.0000e-04
# Epoch 18/500
# 35/35 [==============================] - 1s 17ms/step - loss: 0.1888 - val_loss: 0.1921 - lr: 1.0000e-04
# Epoch 19/500
# 35/35 [==============================] - 1s 17ms/step - loss: 0.1811 - val_loss: 0.1861 - lr: 1.0000e-04
# Epoch 20/500
# 35/35 [==============================] - 1s 17ms/step - loss: 0.1738 - val_loss: 0.1757 - lr: 1.0000e-04
# Epoch 21/500
# 35/35 [==============================] - 1s 17ms/step - loss: 0.1667 - val_loss: 0.1654 - lr: 1.0000e-04
# Epoch 22/500
# 35/35 [==============================] - 1s 17ms/step - loss: 0.1600 - val_loss: 0.1606 - lr: 1.0000e-04
# Epoch 23/500
# 35/35 [==============================] - 1s 17ms/step - loss: 0.1540 - val_loss: 0.1529 - lr: 1.0000e-04
# Epoch 24/500
# 35/35 [==============================] - 1s 17ms/step - loss: 0.1479 - val_loss: 0.1473 - lr: 1.0000e-04
# Epoch 25/500
# 35/35 [==============================] - 1s 17ms/step - loss: 0.1426 - val_loss: 0.1434 - lr: 1.0000e-04
# Epoch 26/500
# 35/35 [==============================] - 1s 17ms/step - loss: 0.1372 - val_loss: 0.1397 - lr: 1.0000e-04
# Epoch 27/500
# 35/35 [==============================] - 1s 17ms/step - loss: 0.1317 - val_loss: 0.1332 - lr: 1.0000e-04
# Epoch 28/500
# 35/35 [==============================] - 1s 17ms/step - loss: 0.1267 - val_loss: 0.1270 - lr: 1.0000e-04
# Epoch 29/500
# 35/35 [==============================] - 1s 17ms/step - loss: 0.1223 - val_loss: 0.1264 - lr: 1.0000e-04
# Epoch 30/500
# 35/35 [==============================] - 1s 16ms/step - loss: 0.1175 - val_loss: 0.1166 - lr: 1.0000e-04
# Epoch 31/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.1129 - val_loss: 0.1129 - lr: 1.0000e-04
# Epoch 32/500
# 35/35 [==============================] - 1s 16ms/step - loss: 0.1086 - val_loss: 0.1078 - lr: 1.0000e-04
# Epoch 33/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.1049 - val_loss: 0.1073 - lr: 1.0000e-04
# Epoch 34/500
# 35/35 [==============================] - 1s 16ms/step - loss: 0.1009 - val_loss: 0.1005 - lr: 1.0000e-04
# Epoch 35/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0974 - val_loss: 0.0972 - lr: 1.0000e-04
# Epoch 36/500
# 35/35 [==============================] - 1s 16ms/step - loss: 0.0936 - val_loss: 0.0942 - lr: 1.0000e-04
# Epoch 37/500
# 35/35 [==============================] - 1s 16ms/step - loss: 0.0905 - val_loss: 0.0900 - lr: 1.0000e-04
# Epoch 38/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0875 - val_loss: 0.0861 - lr: 1.0000e-04
# Epoch 39/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0843 - val_loss: 0.0842 - lr: 1.0000e-04
# Epoch 40/500
# 35/35 [==============================] - 1s 16ms/step - loss: 0.0814 - val_loss: 0.0804 - lr: 1.0000e-04
# Epoch 41/500
# 35/35 [==============================] - 1s 16ms/step - loss: 0.0785 - val_loss: 0.0771 - lr: 1.0000e-04
# Epoch 42/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0759 - val_loss: 0.0750 - lr: 1.0000e-04
# Epoch 43/500
# 35/35 [==============================] - 1s 16ms/step - loss: 0.0735 - val_loss: 0.0726 - lr: 1.0000e-04
# Epoch 44/500
# 35/35 [==============================] - 1s 17ms/step - loss: 0.0710 - val_loss: 0.0703 - lr: 1.0000e-04
# Epoch 45/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0688 - val_loss: 0.0681 - lr: 1.0000e-04
# Epoch 46/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0660 - val_loss: 0.0656 - lr: 1.0000e-04
# Epoch 47/500
# 35/35 [==============================] - 1s 16ms/step - loss: 0.0638 - val_loss: 0.0648 - lr: 1.0000e-04
# Epoch 48/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0620 - val_loss: 0.0611 - lr: 1.0000e-04
# Epoch 49/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0600 - val_loss: 0.0585 - lr: 1.0000e-04
# Epoch 50/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0579 - val_loss: 0.0574 - lr: 1.0000e-04
# Epoch 51/500
# 35/35 [==============================] - 1s 16ms/step - loss: 0.0563 - val_loss: 0.0545 - lr: 1.0000e-04
# Epoch 52/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0544 - val_loss: 0.0525 - lr: 1.0000e-04
# Epoch 53/500
# 35/35 [==============================] - 1s 16ms/step - loss: 0.0529 - val_loss: 0.0519 - lr: 1.0000e-04
# Epoch 54/500
# 35/35 [==============================] - 1s 16ms/step - loss: 0.0511 - val_loss: 0.0488 - lr: 1.0000e-04
# Epoch 55/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0499 - val_loss: 0.0476 - lr: 1.0000e-04
# Epoch 56/500
# 35/35 [==============================] - 1s 16ms/step - loss: 0.0480 - val_loss: 0.0460 - lr: 1.0000e-04
# Epoch 57/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0469 - val_loss: 0.0447 - lr: 1.0000e-04
# Epoch 58/500
# 35/35 [==============================] - 1s 16ms/step - loss: 0.0455 - val_loss: 0.0443 - lr: 1.0000e-04
# Epoch 59/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0435 - val_loss: 0.0425 - lr: 1.0000e-04
# Epoch 60/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0427 - val_loss: 0.0409 - lr: 1.0000e-04
# Epoch 61/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0408 - val_loss: 0.0398 - lr: 1.0000e-04
# Epoch 62/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0399 - val_loss: 0.0379 - lr: 1.0000e-04
# Epoch 63/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0388 - val_loss: 0.0369 - lr: 1.0000e-04
# Epoch 64/500
# 35/35 [==============================] - 1s 16ms/step - loss: 0.0378 - val_loss: 0.0354 - lr: 1.0000e-04
# Epoch 65/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0365 - val_loss: 0.0347 - lr: 1.0000e-04
# Epoch 66/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0353 - val_loss: 0.0335 - lr: 1.0000e-04
# Epoch 67/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0346 - val_loss: 0.0330 - lr: 1.0000e-04
# Epoch 68/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0338 - val_loss: 0.0316 - lr: 1.0000e-04
# Epoch 69/500
# 35/35 [==============================] - 1s 16ms/step - loss: 0.0329 - val_loss: 0.0313 - lr: 1.0000e-04
# Epoch 70/500
# 35/35 [==============================] - 1s 16ms/step - loss: 0.0316 - val_loss: 0.0300 - lr: 1.0000e-04
# Epoch 71/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0310 - val_loss: 0.0301 - lr: 1.0000e-04
# Epoch 72/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0299 - val_loss: 0.0278 - lr: 1.0000e-04
# Epoch 73/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0293 - val_loss: 0.0272 - lr: 1.0000e-04
# Epoch 74/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0283 - val_loss: 0.0265 - lr: 1.0000e-04
# Epoch 75/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0273 - val_loss: 0.0257 - lr: 1.0000e-04
# Epoch 76/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0266 - val_loss: 0.0248 - lr: 1.0000e-04
# Epoch 77/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0262 - val_loss: 0.0244 - lr: 1.0000e-04
# Epoch 78/500
# 35/35 [==============================] - 1s 16ms/step - loss: 0.0251 - val_loss: 0.0237 - lr: 1.0000e-04
# Epoch 79/500
# 35/35 [==============================] - 1s 16ms/step - loss: 0.0250 - val_loss: 0.0228 - lr: 1.0000e-04
# Epoch 80/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0236 - val_loss: 0.0222 - lr: 1.0000e-04
# Epoch 81/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0234 - val_loss: 0.0215 - lr: 1.0000e-04
# Epoch 82/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0229 - val_loss: 0.0212 - lr: 1.0000e-04
# Epoch 83/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0225 - val_loss: 0.0207 - lr: 1.0000e-04
# Epoch 84/500
# 35/35 [==============================] - 1s 16ms/step - loss: 0.0219 - val_loss: 0.0207 - lr: 1.0000e-04
# Epoch 85/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0212 - val_loss: 0.0191 - lr: 1.0000e-04
# Epoch 86/500
# 35/35 [==============================] - 1s 16ms/step - loss: 0.0206 - val_loss: 0.0188 - lr: 1.0000e-04
# Epoch 87/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0199 - val_loss: 0.0185 - lr: 1.0000e-04
# Epoch 88/500
# 35/35 [==============================] - 1s 16ms/step - loss: 0.0196 - val_loss: 0.0178 - lr: 1.0000e-04
# Epoch 89/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0188 - val_loss: 0.0171 - lr: 1.0000e-04
# Epoch 90/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0185 - val_loss: 0.0167 - lr: 1.0000e-04
# Epoch 91/500
# 35/35 [==============================] - 1s 16ms/step - loss: 0.0179 - val_loss: 0.0161 - lr: 1.0000e-04
# Epoch 92/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0176 - val_loss: 0.0163 - lr: 1.0000e-04
# Epoch 93/500
# 35/35 [==============================] - 1s 16ms/step - loss: 0.0168 - val_loss: 0.0155 - lr: 1.0000e-04
# Epoch 94/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0168 - val_loss: 0.0154 - lr: 1.0000e-04
# Epoch 95/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0158 - val_loss: 0.0145 - lr: 1.0000e-04
# Epoch 96/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0157 - val_loss: 0.0141 - lr: 1.0000e-04
# Epoch 97/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0154 - val_loss: 0.0138 - lr: 1.0000e-04
# Epoch 98/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0151 - val_loss: 0.0133 - lr: 1.0000e-04
# Epoch 99/500
# 35/35 [==============================] - 1s 16ms/step - loss: 0.0149 - val_loss: 0.0133 - lr: 1.0000e-04
# Epoch 100/500
# 35/35 [==============================] - 1s 16ms/step - loss: 0.0140 - val_loss: 0.0127 - lr: 1.0000e-04
# Epoch 101/500
# 35/35 [==============================] - 1s 16ms/step - loss: 0.0139 - val_loss: 0.0128 - lr: 1.0000e-04
# Epoch 102/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0136 - val_loss: 0.0131 - lr: 1.0000e-04
# Epoch 103/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0136 - val_loss: 0.0119 - lr: 1.0000e-04
# Epoch 104/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0129 - val_loss: 0.0114 - lr: 1.0000e-04
# Epoch 105/500
# 35/35 [==============================] - 1s 16ms/step - loss: 0.0130 - val_loss: 0.0117 - lr: 1.0000e-04
# Epoch 106/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0124 - val_loss: 0.0110 - lr: 1.0000e-04
# Epoch 107/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0121 - val_loss: 0.0112 - lr: 1.0000e-04
# Epoch 108/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0119 - val_loss: 0.0103 - lr: 1.0000e-04
# Epoch 109/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0117 - val_loss: 0.0102 - lr: 1.0000e-04
# Epoch 110/500
# 35/35 [==============================] - 1s 16ms/step - loss: 0.0112 - val_loss: 0.0098 - lr: 1.0000e-04
# Epoch 111/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0112 - val_loss: 0.0096 - lr: 1.0000e-04
# Epoch 112/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0109 - val_loss: 0.0096 - lr: 1.0000e-04
# Epoch 113/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0105 - val_loss: 0.0090 - lr: 1.0000e-04
# Epoch 114/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0104 - val_loss: 0.0089 - lr: 1.0000e-04
# Epoch 115/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0102 - val_loss: 0.0089 - lr: 1.0000e-04
# Epoch 116/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0104 - val_loss: 0.0087 - lr: 1.0000e-04
# Epoch 117/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0100 - val_loss: 0.0086 - lr: 1.0000e-04
# Epoch 118/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0096 - val_loss: 0.0082 - lr: 1.0000e-04
# Epoch 119/500
# 35/35 [==============================] - 1s 16ms/step - loss: 0.0094 - val_loss: 0.0078 - lr: 1.0000e-04
# Epoch 120/500
# 35/35 [==============================] - 1s 16ms/step - loss: 0.0091 - val_loss: 0.0077 - lr: 1.0000e-04
# Epoch 121/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0092 - val_loss: 0.0084 - lr: 1.0000e-04
# Epoch 122/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0091 - val_loss: 0.0076 - lr: 1.0000e-04
# Epoch 123/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0087 - val_loss: 0.0072 - lr: 1.0000e-04
# Epoch 124/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0086 - val_loss: 0.0072 - lr: 1.0000e-04
# Epoch 125/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0087 - val_loss: 0.0071 - lr: 1.0000e-04
# Epoch 126/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0083 - val_loss: 0.0067 - lr: 1.0000e-04
# Epoch 127/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0080 - val_loss: 0.0068 - lr: 1.0000e-04
# Epoch 128/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0076 - val_loss: 0.0069 - lr: 1.0000e-04
# Epoch 129/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0078 - val_loss: 0.0069 - lr: 1.0000e-04
# Epoch 130/500
# 35/35 [==============================] - 1s 16ms/step - loss: 0.0077 - val_loss: 0.0062 - lr: 1.0000e-04
# Epoch 131/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0072 - val_loss: 0.0062 - lr: 1.0000e-04
# Epoch 132/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0074 - val_loss: 0.0061 - lr: 1.0000e-04
# Epoch 133/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0072 - val_loss: 0.0059 - lr: 1.0000e-04
# Epoch 134/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0072 - val_loss: 0.0063 - lr: 1.0000e-04
# Epoch 135/500
# 35/35 [==============================] - 1s 16ms/step - loss: 0.0071 - val_loss: 0.0055 - lr: 1.0000e-04
# Epoch 136/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0069 - val_loss: 0.0056 - lr: 1.0000e-04
# Epoch 137/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0069 - val_loss: 0.0053 - lr: 1.0000e-04
# Epoch 138/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0068 - val_loss: 0.0053 - lr: 1.0000e-04
# Epoch 139/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0066 - val_loss: 0.0052 - lr: 1.0000e-04
# Epoch 140/500
# 35/35 [==============================] - 1s 17ms/step - loss: 0.0063 - val_loss: 0.0052 - lr: 1.0000e-04
# Epoch 141/500
# 35/35 [==============================] - 1s 17ms/step - loss: 0.0064 - val_loss: 0.0051 - lr: 1.0000e-04
# Epoch 142/500
# 35/35 [==============================] - 1s 16ms/step - loss: 0.0061 - val_loss: 0.0050 - lr: 1.0000e-04
# Epoch 143/500
# 35/35 [==============================] - 1s 16ms/step - loss: 0.0063 - val_loss: 0.0051 - lr: 1.0000e-04
# Epoch 144/500
# 35/35 [==============================] - 1s 16ms/step - loss: 0.0059 - val_loss: 0.0047 - lr: 1.0000e-04
# Epoch 145/500
# 35/35 [==============================] - 1s 16ms/step - loss: 0.0060 - val_loss: 0.0047 - lr: 1.0000e-04
# Epoch 146/500
# 35/35 [==============================] - 1s 19ms/step - loss: 0.0059 - val_loss: 0.0047 - lr: 1.0000e-04
# Epoch 147/500
# 35/35 [==============================] - 1s 18ms/step - loss: 0.0060 - val_loss: 0.0048 - lr: 1.0000e-04
# Epoch 148/500
# 35/35 [==============================] - 1s 16ms/step - loss: 0.0058 - val_loss: 0.0052 - lr: 1.0000e-04
# Epoch 149/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0055 - val_loss: 0.0047 - lr: 1.0000e-04
# Epoch 150/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0056 - val_loss: 0.0043 - lr: 5.0000e-05
# Epoch 151/500
# 35/35 [==============================] - 1s 16ms/step - loss: 0.0054 - val_loss: 0.0044 - lr: 5.0000e-05
# Epoch 152/500
# 35/35 [==============================] - 1s 16ms/step - loss: 0.0053 - val_loss: 0.0045 - lr: 5.0000e-05
# Epoch 153/500
# 35/35 [==============================] - 1s 17ms/step - loss: 0.0054 - val_loss: 0.0042 - lr: 5.0000e-05
# Epoch 154/500
# 35/35 [==============================] - 1s 18ms/step - loss: 0.0054 - val_loss: 0.0042 - lr: 5.0000e-05
# Epoch 155/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0058 - val_loss: 0.0042 - lr: 5.0000e-05
# Epoch 156/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0052 - val_loss: 0.0042 - lr: 5.0000e-05
# Epoch 157/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0052 - val_loss: 0.0041 - lr: 5.0000e-05
# Epoch 158/500
# 35/35 [==============================] - 1s 16ms/step - loss: 0.0054 - val_loss: 0.0040 - lr: 5.0000e-05
# Epoch 159/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0052 - val_loss: 0.0043 - lr: 5.0000e-05
# Epoch 160/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0050 - val_loss: 0.0042 - lr: 5.0000e-05
# Epoch 161/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0051 - val_loss: 0.0040 - lr: 5.0000e-05
# Epoch 162/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0051 - val_loss: 0.0041 - lr: 5.0000e-05
# Epoch 163/500
# 35/35 [==============================] - 1s 16ms/step - loss: 0.0054 - val_loss: 0.0041 - lr: 5.0000e-05
# Epoch 164/500
# 35/35 [==============================] - 1s 16ms/step - loss: 0.0049 - val_loss: 0.0040 - lr: 2.5000e-05
# Epoch 165/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0050 - val_loss: 0.0039 - lr: 2.5000e-05
# Epoch 166/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0048 - val_loss: 0.0039 - lr: 2.5000e-05
# Epoch 167/500
# 35/35 [==============================] - 1s 16ms/step - loss: 0.0050 - val_loss: 0.0043 - lr: 2.5000e-05
# Epoch 168/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0047 - val_loss: 0.0038 - lr: 2.5000e-05
# Epoch 169/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0051 - val_loss: 0.0038 - lr: 2.5000e-05
# Epoch 170/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0049 - val_loss: 0.0038 - lr: 2.5000e-05
# Epoch 171/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0048 - val_loss: 0.0038 - lr: 2.5000e-05
# Epoch 172/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0049 - val_loss: 0.0038 - lr: 2.5000e-05
# Epoch 173/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0048 - val_loss: 0.0037 - lr: 2.5000e-05
# Epoch 174/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0049 - val_loss: 0.0043 - lr: 2.5000e-05
# Epoch 175/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0049 - val_loss: 0.0038 - lr: 1.2500e-05
# Epoch 176/500
# 35/35 [==============================] - 1s 16ms/step - loss: 0.0047 - val_loss: 0.0038 - lr: 1.2500e-05
# Epoch 177/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0047 - val_loss: 0.0038 - lr: 1.2500e-05
# Epoch 178/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0047 - val_loss: 0.0037 - lr: 1.2500e-05
# Epoch 179/500
# 35/35 [==============================] - 1s 17ms/step - loss: 0.0048 - val_loss: 0.0037 - lr: 1.2500e-05
# Epoch 180/500
# 35/35 [==============================] - 1s 18ms/step - loss: 0.0048 - val_loss: 0.0037 - lr: 6.2500e-06
# Epoch 181/500
# 35/35 [==============================] - 1s 19ms/step - loss: 0.0047 - val_loss: 0.0038 - lr: 6.2500e-06
# Epoch 182/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0047 - val_loss: 0.0037 - lr: 6.2500e-06
# Epoch 183/500
# 35/35 [==============================] - 1s 15ms/step - loss: 0.0045 - val_loss: 0.0038 - lr: 6.2500e-06
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0033
# Test loss: 0.003268592990934849
# 1/1 [==============================] - 1s 758ms/step
#    Actual Price  Predicted Price
# 0      0.614941         0.622906
# RMSE: 0.007964973929281527
# Files saved:
# 1. Comparison table: 'xrp_comparison_table_multiple_features_with_val_v2.png'
# 2. Test loss plot: 'xrp_test_loss_plot_multiple_features_with_val_v2.png'
# 3. Results plot: 'xrp_price_prediction_multiple_features_with_val_v2.png'
